# %% [markdown]
# # 시계열 데이터 분석

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as spst
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %% [markdown]
# ### (2) 데이터

# %% [markdown]
# * KOSPI 지수 데이터

# %%
kospi = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/KOSPI.csv"
                   , usecols= ['Date', 'Close', 'Volume'])

kospi['Date'] = pd.to_datetime(kospi['Date'])
kospi['Year'] = kospi['Date'].dt.year
kospi['Month'] = kospi['Date'].dt.month
kospi['Weekday'] = kospi['Date'].dt.weekday

kospi['Close_Lag'] = kospi['Close'].shift()
kospi['Volume_Lag'] = kospi['Volume'].shift()
kospi.drop('Volume', axis = 1, inplace = True)
kospi.dropna(axis=0, inplace=True)

kospi.head()
# Out:
#         Date    Close  Year  Month  Weekday  Close_Lag  Volume_Lag
# 1 2014-10-01  1991.54  2014     10        2    2020.09    322812.0
# 2 2014-10-02  1976.16  2014     10        3    1991.54    351581.0
# 3 2014-10-06  1968.39  2014     10        0    1976.16    322656.0
# 4 2014-10-07  1972.91  2014     10        1    1968.39    325078.0
# 5 2014-10-08  1965.25  2014     10        2    1972.91    328234.0

# %% [markdown]
# * 서울시 공유자전거

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/SeoulBike_Simple.csv'
bike = pd.read_csv(path)
bike['Datetime'] = pd.to_datetime(bike['Datetime'] )
bike.rename(columns={'Rented Bike Count':'Count'}, inplace = True)
bike = bike.loc[bike['Datetime'].between('2018-06-11','2018-08-13', inclusive = 'left'),
                      ['Datetime', 'Temperature', 'Humidity','Count']]
bike.reset_index(drop = True, inplace = True)

# %% [markdown]
# * 유통점 판매데이터

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/retail_demand2.csv'
retail = pd.read_csv(path)
retail['date'] = pd.to_datetime(retail['date'])
# retail = retail.loc[retail['date'].between('2013-06-01', '2015-10-31')].reset_index(drop = True)
retail
# Out:
#            date  item  sales  tot_sales  comp_sales
# 0    2013-01-01    28     45        456          43
# 1    2013-01-02    28     53        474          57
# 2    2013-01-03    28     65        519          45
# 3    2013-01-04    28     66        527          45
# 4    2013-01-05    28     97        575          55
# ...         ...   ...    ...        ...         ...
# 1821 2017-12-27    28     82        680          79
# 1822 2017-12-28    28    114        743          68
# 1823 2017-12-29    28    101        776          67
# 1824 2017-12-30    28    120        901          79
# 1825 2017-12-31    28    104        870          73
#
# [1826 rows x 5 columns]

# %% [markdown]
# ## 2.시계열 데이터란?
#
# * 데이터셋
#     * 일반 데이터셋 : 분석단위(행) 하나 하나가 개별 instance 입니다.
#     * 시계열 데이터 : 데이터 분석 단위(행) 간에 (시간) 순서(sequence)가 있는 데이터
#
# * 시계열 데이터 구분은, 비즈니스 이해단계에서 [문제정의]시 결정 됩니다.
#     * 해결해야 할 문제가 시간 순서 관점이 필요한지 아닌지.

# %% [markdown]
# * KOSPI 2014.10 ~ 2019.09 데이터
#     * Close : 코스피 종가(target)
#     * Weekday : 요일 (0-월요일, 6-일요일)
#     * Close_Lag : 전날 종가
#     * Volume_Lag : 전날 거래량

# %%
plt.figure(figsize = (10,6))
plt.plot('Date', 'Close', data = kospi, linewidth = .7)
plt.grid()
plt.show()

# %% [markdown]
# * 시계열 데이터는 시간(시기)을 고려해야 합니다.
#     * 어느 기간?
#     * 반복되는 주기?

# %% [markdown]
# ## 3.기존 분석 방식 적용시 문제점

# %% [markdown]
# ### (1) 단변량분석

# %% [markdown]
# #### 1) 숫자

# %% [markdown]
# * Close의 분포를 살펴보면…
#     * 하나의 박스플롯으로 설명이 되나요?
#     * 히스트그램을 보면 분포가 여러 개로 나뉘어 보입니다. 어떻게 해석해야 할까요?

# %%
sns.histplot(x = 'Close', data = kospi, bins = 50)
plt.show()

# %%
sns.boxplot(x = 'Close', data = kospi)
plt.show()

# %% [markdown]
# #### 2) 범주

# %%
sns.countplot(x="Weekday", data = kospi)
plt.show()

# %%
temp = kospi['Weekday'].value_counts()

plt.pie(temp.values, labels = temp.index, autopct='%.2f%%')
plt.show()

# %% [markdown]
# ### (2) 이변량

# %% [markdown]
# #### 1) 숫자 vs 숫자

# %% [markdown]
# * 전날 종가와 오늘 종가를 비교해 보겠습니다.
#     * 산점도 : 완전 직선
#     * 상관분석 : 상관계수 거의 1, p-value 는 0!
#     * 그러면 전날 종가만 있으면 다음날 코스피 지수 예측은 확실한가요?

# %%
sns.regplot(x = 'Close_Lag', y = 'Close', data = kospi,  line_kws={'color': 'darkred'})
plt.show()

# %%
# 상관계수와 p-value
spst.pearsonr(kospi['Close_Lag'], kospi['Close'])
# Out:
# PearsonRResult(statistic=0.9961042261752662, pvalue=0.0)

# %% [markdown]
# #### 2) 범주 vs 숫자

# %% [markdown]
# * 요일별로 주가가 달라질까요?
#     * 요일은 주가와 아무런 관련이 없어 보입니다.
#     * 진짜 그럴까요?

# %%
temp = kospi.loc[kospi.Date.between('2019-01-01','2019-01-31')]

sns.barplot(x="Weekday", y="Close", data = temp)
plt.grid()
plt.show()

# %% [markdown]
# ## 4.시계열 데이터 분석 방법

# %% [markdown]
# ### (1) 시간의 흐름에 따른 패턴 찾기

# %% [markdown]
# #### 1) 시간의 흐름에 따른 추세 분석 : 라인차트

# %% [markdown]
# * KOSPI 지수 라인차트 그리기

# %%
plt.figure(figsize = (12,4))
sns.lineplot(x = 'Date', y = 'Close', data = kospi, linewidth = .7)
plt.show()

# %% [markdown]
# * 지수와 거래량을 한꺼번에 라인차트로 그리기

# %%
# 거래량 추가
plt.figure(figsize = (12,5))
sns.lineplot(x = 'Date', y = 'Close', data = kospi, label = 'Close', color = 'blue', linewidth = .7)
sns.lineplot(x = 'Date', y = 'Volume_Lag', data = kospi, label = 'Volume', color = 'green', linewidth = .5)
plt.show()

# %%
# 축을 양쪽에 두고 그립시다.
plt.figure(figsize = (12,5))
# 왼쪽 축
ax1 = sns.lineplot(x = 'Date', y = 'Close', data = kospi, label = 'Close', color = 'blue', linewidth = .5)
plt.legend(loc='upper left')

 # 오른쪽 축 생성
ax2 = ax1.twinx()
sns.lineplot(x = 'Date', y = 'Volume_Lag', data = kospi, label = 'Volume', color = 'green', linewidth = .5)
plt.legend(loc='upper right')

# 그래프 출력
plt.show()

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] bike의 수요량(Count) 그래프를 그려봅시다.
# > * 처음부터 400개 데이터만 뽑아서 라인차트를 그립니다.
# > * 그래프를 관찰하고 패턴을 찾아 적어 봅시다.

# %%
bike.head()
# Out:
#              Datetime  Temperature  Humidity  Count
# 0 2018-06-11 00:00:00         20.3      58.0    918
# 1 2018-06-11 01:00:00         19.8      59.0    555
# 2 2018-06-11 02:00:00         19.2      60.0    353
# 3 2018-06-11 03:00:00         18.8      61.0    232
# 4 2018-06-11 04:00:00         18.8      60.0    194

# %%
temp = bike.iloc[:400]
plt.figure(figsize = (12,5))
sns.lineplot(x = 'Datetime', y = 'Count', data = temp)
plt.grid()
plt.show()

# %%
# 일단위 패턴 : 출퇴근 시간대, 밤-새벽시간, 오후시간
# 주단위 패턴 : 평일과 주말 패턴 차이

# %% [markdown]
# [문2] bike의 대여량(Count)과 온도(Temperature) 그래프를 그려봅시다.
# > * 처음부터 400개 데이터만 뽑아서 라인차트를 그립니다.
# > * 그래프를 관찰하고 패턴을 찾아 적어 봅시다.

# %%
# 축을 양쪽에 두고 그립시다.
plt.figure(figsize = (12,5))
# 왼쪽 축
ax1 = sns.lineplot(x = 'Datetime', y = 'Count', data = temp, label = 'Count', color = 'blue', linewidth = .5)
plt.legend(loc='upper left')

 # 오른쪽 축 생성
ax2 = ax1.twinx()
sns.lineplot(x = 'Datetime', y = 'Temperature', data = temp, label = 'Temperature', color = 'green', linewidth = .5)
plt.legend(loc='upper right')

# 그래프 출력
plt.grid()
plt.show()

# %% [markdown]
# #### 2) 시계열 데이터 분해(Decomposition)
# * 시계열 데이터 안에 있는 반복 추세와 반복 패턴을 찾아내는 과정입니다.
# * 찾아낸 패턴을 하나의 모델로 볼 수도 있습니다.

# %% [markdown]
# ① 시계열 데이터 분해 결과 시각화 함수

# %%
def decomp_plot(decomp) :
    # 시계열 분해 결과를 받아서 데이터프레임으로 저장
    result = pd.DataFrame({'observed':decomp.observed, 'trend':decomp.trend, 'seasonal':decomp.seasonal, 'residual':decomp.resid})

    # 4개의 그래프로 나눠서 그리기
    plt.subplot(4,1,1)
    plt.plot(result['observed'])
    plt.ylabel('observed')

    plt.subplot(4,1,2)
    plt.plot(result['trend'])
    plt.ylabel('trend')

    plt.subplot(4,1,3)
    plt.plot(result['seasonal'])
    plt.ylabel('seasonal')

    plt.subplot(4,1,4)
    plt.plot(result['residual'])
    plt.ylabel('residual')
    plt.show()

    return result

# %% [markdown]
# ① 시계열 데이터를 분해해 봅시다.
# * freq 를 조절하며 계절성(seasonal)을 도출해 봅시다.
# * 그래프는 위에서 만든 decomp_plot 을 사용합니다.

# %% [markdown]
# * 1일(24시간)의 계절성 고려

# %%
# 시계열 데이터 분해
decomp = sm.tsa.seasonal_decompose(bike['Count'], model = 'additive', period = 24)

# 그래프 그리기
plt.figure(figsize=(12, 8))
result = decomp_plot(decomp)

# %% [markdown]
# * 1주일(7일 * 24시간)의 계절성 고려

# %%
# 시계열 데이터 분해
decomp = sm.tsa.seasonal_decompose(bike['Count'], model = 'additive', period = 24 * 7)

# 그래프 그리기
plt.figure(figsize=(12, 8))
result = decomp_plot(decomp)

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] retail의 판매량(sales)에 대한 시계열 데이터 분해를 수행해 봅시다.
# * 먼저 라인차트를 그려서 주기, 패턴을 찾습니다.
#     * 전체 데이터에 대해 라인차트 그리기
#     * 데이터의 일부(약 1 ~ 2개월)에 대해 라인차트 그리기

# %%
retail.head()
# Out:
#         date  item  sales  tot_sales  comp_sales
# 0 2013-01-01    28     45        456          43
# 1 2013-01-02    28     53        474          57
# 2 2013-01-03    28     65        519          45
# 3 2013-01-04    28     66        527          45
# 4 2013-01-05    28     97        575          55

# %%
# 라인차트 그리기
plt.figure(figsize = (12,4))
sns.lineplot(x = 'date', y = 'sales', data = retail, linewidth = .7)
plt.show()

# %%
# 라인차트 그리기
temp = retail.iloc[:90]
plt.figure(figsize = (12,4))
sns.lineplot(x = 'date', y = 'sales', data = temp, linewidth = .7)
plt.show()

# %% [markdown]
# [문1] retail의 판매량(sales)에 대한 시계열 데이터 분해를 수행해 봅시다.
# * 찾은 패턴을 기반으로 시계열 데이터를 분해 하고 그래프로 그려봅니다.
#     * 주기 7과 365, 두 가지를 기준으로 각각 분해해 봅시다.

# %%
retail.head()
# Out:
#         date  item  sales  tot_sales  comp_sales
# 0 2013-01-01    28     45        456          43
# 1 2013-01-02    28     53        474          57
# 2 2013-01-03    28     65        519          45
# 3 2013-01-04    28     66        527          45
# 4 2013-01-05    28     97        575          55

# %%
# 시계열 데이터 분해
decomp = sm.tsa.seasonal_decompose(retail['sales'], model = 'additive', period = 7)

# 그래프 그리기
plt.figure(figsize=(12, 8))
result = decomp_plot(decomp)

# %%
# 시계열 데이터 분해
decomp = sm.tsa.seasonal_decompose(retail['sales'], model = 'additive', period = 365)

# 그래프 그리기
plt.figure(figsize=(12, 8))
result = decomp_plot(decomp)

# %% [markdown]
# #### 3) [참조]자기상관함수(ACF)

# %%
plot_acf(bike['Count'], lags = 60)
plt.grid()
plt.show()

# %%
# 반복문으로 시차를 늘려가면서 데이터셋 만들기
temp = bike[['Count']].copy()

for i in range(1,21) :
    var = 'lag' + str(i)
    temp[var] = temp['Count'].shift(i)

# %%
temp.head(20)
# Out:
#     Count    lag1    lag2    lag3    lag4    lag5    lag6    lag7    lag8  \
# 0     918     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     555   918.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     353   555.0   918.0     NaN     NaN     NaN     NaN     NaN     NaN
# 3     232   353.0   555.0   918.0     NaN     NaN     NaN     NaN     NaN
# 4     194   232.0   353.0   555.0   918.0     NaN     NaN     NaN     NaN
# 5     324   194.0   232.0   353.0   555.0   918.0     NaN     NaN     NaN
# 6     807   324.0   194.0   232.0   353.0   555.0   918.0     NaN     NaN
# 7    1629   807.0   324.0   194.0   232.0   353.0   555.0   918.0     NaN
# 8    2375  1629.0   807.0   324.0   194.0   232.0   353.0   555.0   918.0
# 9    1307  2375.0  1629.0   807.0   324.0   194.0   232.0   353.0   555.0
# 10    992  1307.0  2375.0  1629.0   807.0   324.0   194.0   232.0   353.0
# 11   1107   992.0  1307.0  2375.0  1629.0   807.0   324.0   194.0   232.0
# 12   1204  1107.0   992.0  1307.0  2375.0  1629.0   807.0   324.0   194.0
# 13   1033  1204.0  1107.0   992.0  1307.0  2375.0  1629.0   807.0   324.0
# 14   1075  1033.0  1204.0  1107.0   992.0  1307.0  2375.0  1629.0   807.0
# 15   1240  1075.0  1033.0  1204.0  1107.0   992.0  1307.0  2375.0  1629.0
# 16   1220  1240.0  1075.0  1033.0  1204.0  1107.0   992.0  1307.0  2375.0
# 17   1475  1220.0  1240.0  1075.0  1033.0  1204.0  1107.0   992.0  1307.0
# 18   1491  1475.0  1220.0  1240.0  1075.0  1033.0  1204.0  1107.0   992.0
# 19    873  1491.0  1475.0  1220.0  1240.0  1075.0  1033.0  1204.0  1107.0
#
#       lag9  ...   lag11   lag12  lag13  lag14  lag15  lag16  lag17  lag18  \
# 0      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8      NaN  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9    918.0  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10   555.0  ...     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11   353.0  ...   918.0     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12   232.0  ...   555.0   918.0    NaN    NaN    NaN    NaN    NaN    NaN
# 13   194.0  ...   353.0   555.0  918.0    NaN    NaN    NaN    NaN    NaN
# 14   324.0  ...   232.0   353.0  555.0  918.0    NaN    NaN    NaN    NaN
# 15   807.0  ...   194.0   232.0  353.0  555.0  918.0    NaN    NaN    NaN
# 16  1629.0  ...   324.0   194.0  232.0  353.0  555.0  918.0    NaN    NaN
# 17  2375.0  ...   807.0   324.0  194.0  232.0  353.0  555.0  918.0    NaN
# 18  1307.0  ...  1629.0   807.0  324.0  194.0  232.0  353.0  555.0  918.0
# 19   992.0  ...  2375.0  1629.0  807.0  324.0  194.0  232.0  353.0  555.0
#
#     lag19  lag20
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# 6     NaN    NaN
# 7     NaN    NaN
# 8     NaN    NaN
# 9     NaN    NaN
# 10    NaN    NaN
# 11    NaN    NaN
# 12    NaN    NaN
# 13    NaN    NaN
# 14    NaN    NaN
# 15    NaN    NaN
# 16    NaN    NaN
# 17    NaN    NaN
# 18    NaN    NaN
# 19  918.0    NaN
#
# [20 rows x 21 columns]

# %%
# 각 시차간의 상관계수
temp.corr()
# Out:
#           Count      lag1      lag2      lag3      lag4      lag5      lag6  \
# Count  1.000000  0.863432  0.658848  0.474569  0.299944  0.130073 -0.005645
# lag1   0.863432  1.000000  0.863546  0.659080  0.474695  0.300006  0.130175
# lag2   0.658848  0.863546  1.000000  0.863567  0.659076  0.474690  0.299992
# lag3   0.474569  0.659080  0.863567  1.000000  0.863567  0.659087  0.474652
# lag4   0.299944  0.474695  0.659076  0.863567  1.000000  0.863570  0.659071
# lag5   0.130073  0.300006  0.474690  0.659087  0.863570  1.000000  0.863574
# lag6  -0.005645  0.130175  0.299992  0.474652  0.659071  0.863574  1.000000
# lag7  -0.099771 -0.005589  0.130162  0.299963  0.474638  0.659067  0.863573
# lag8  -0.144991 -0.099816 -0.005580  0.130203  0.299989  0.474651  0.659107
# lag9  -0.115236 -0.145108 -0.099793 -0.005489  0.130262  0.300025  0.474736
# lag10 -0.038991 -0.115413 -0.145079 -0.099664 -0.005409  0.130311  0.300146
# lag11 -0.029932 -0.039152 -0.115381 -0.144959 -0.099595 -0.005372  0.130412
# lag12 -0.044479 -0.030108 -0.039110 -0.115244 -0.144888 -0.099564 -0.005277
# lag13 -0.057788 -0.044730 -0.030050 -0.038903 -0.115145 -0.144858 -0.099451
# lag14 -0.085925 -0.058065 -0.044670 -0.029823 -0.038779 -0.115108 -0.144747
# lag15 -0.170757 -0.086165 -0.058015 -0.044481 -0.029715 -0.038732 -0.115004
# lag16 -0.212503 -0.171045 -0.086116 -0.057810 -0.044365 -0.029663 -0.038603
# lag17 -0.182588 -0.212937 -0.171018 -0.085847 -0.057658 -0.044300 -0.029482
# lag18 -0.106838 -0.183044 -0.212930 -0.170772 -0.085697 -0.057595 -0.044113
# lag19  0.004349 -0.107295 -0.183030 -0.212693 -0.170657 -0.085646 -0.057401
# lag20  0.142140  0.003986 -0.107242 -0.182789 -0.212600 -0.170643 -0.085477
#
#            lag7      lag8      lag9  ...     lag11     lag12     lag13  \
# Count -0.099771 -0.144991 -0.115236  ... -0.029932 -0.044479 -0.057788
# lag1  -0.005589 -0.099816 -0.145108  ... -0.039152 -0.030108 -0.044730
# lag2   0.130162 -0.005580 -0.099793  ... -0.115381 -0.039110 -0.030050
# lag3   0.299963  0.130203 -0.005489  ... -0.144959 -0.115244 -0.038903
# lag4   0.474638  0.299989  0.130262  ... -0.099595 -0.144888 -0.115145
# lag5   0.659067  0.474651  0.300025  ... -0.005372 -0.099564 -0.144858
# lag6   0.863573  0.659107  0.474736  ...  0.130412 -0.005277 -0.099451
# lag7   1.000000  0.863598  0.659172  ...  0.300228  0.130487 -0.005193
# lag8   0.863598  1.000000  0.863606  ...  0.474838  0.300217  0.130454
# lag9   0.659172  0.863606  1.000000  ...  0.659163  0.474787  0.300126
# lag10  0.474836  0.659191  0.863602  ...  0.863580  0.659103  0.474668
# lag11  0.300228  0.474838  0.659163  ...  1.000000  0.863557  0.659036
# lag12  0.130487  0.300217  0.474787  ...  0.863557  1.000000  0.863534
# lag13 -0.005193  0.130454  0.300126  ...  0.659036  0.863534  1.000000
# lag14 -0.099381 -0.005256  0.130316  ...  0.474547  0.658954  0.863480
# lag15 -0.144693 -0.099450 -0.005403  ...  0.299797  0.474422  0.658839
# lag16 -0.114940 -0.144779 -0.099633  ...  0.129910  0.299613  0.474225
# lag17 -0.038496 -0.115063 -0.145061  ... -0.006000  0.129594  0.299256
# lag18 -0.029364 -0.038599 -0.115356  ... -0.100447 -0.006410  0.129108
# lag19 -0.043994 -0.029473 -0.038880  ... -0.145996 -0.100949 -0.007028
# lag20 -0.057295 -0.044100 -0.029727  ... -0.116260 -0.146482 -0.101580
#
#           lag14     lag15     lag16     lag17     lag18     lag19     lag20
# Count -0.085925 -0.170757 -0.212503 -0.182588 -0.106838  0.004349  0.142140
# lag1  -0.058065 -0.086165 -0.171045 -0.212937 -0.183044 -0.107295  0.003986
# lag2  -0.044670 -0.058015 -0.086116 -0.171018 -0.212930 -0.183030 -0.107242
# lag3  -0.029823 -0.044481 -0.057810 -0.085847 -0.170772 -0.212693 -0.182789
# lag4  -0.038779 -0.029715 -0.044365 -0.057658 -0.085697 -0.170657 -0.212600
# lag5  -0.115108 -0.038732 -0.029663 -0.044300 -0.057595 -0.085646 -0.170643
# lag6  -0.144747 -0.115004 -0.038603 -0.029482 -0.044113 -0.057401 -0.085477
# lag7  -0.099381 -0.144693 -0.114940 -0.038496 -0.029364 -0.043994 -0.057295
# lag8  -0.005256 -0.099450 -0.144779 -0.115063 -0.038599 -0.029473 -0.044100
# lag9   0.130316 -0.005403 -0.099633 -0.145061 -0.115356 -0.038880 -0.029727
# lag10  0.299948  0.130120 -0.005655 -0.100027 -0.145511 -0.115831 -0.039276
# lag11  0.474547  0.299797  0.129910 -0.006000 -0.100447 -0.145996 -0.116260
# lag12  0.658954  0.474422  0.299613  0.129594 -0.006410 -0.100949 -0.146482
# lag13  0.863480  0.658839  0.474225  0.299256  0.129108 -0.007028 -0.101580
# lag14  1.000000  0.863434  0.658701  0.473936  0.298837  0.128537 -0.007648
# lag15  0.863434  1.000000  0.863389  0.658567  0.473695  0.298472  0.128091
# lag16  0.658701  0.863389  1.000000  0.863342  0.658404  0.473405  0.298083
# lag17  0.473936  0.658567  0.863342  1.000000  0.863235  0.658116  0.472985
# lag18  0.298837  0.473695  0.658404  0.863235  1.000000  0.863111  0.657821
# lag19  0.128537  0.298472  0.473405  0.658116  0.863111  1.000000  0.862985
# lag20 -0.007648  0.128091  0.298083  0.472985  0.657821  0.862985  1.000000
#
# [21 rows x 21 columns]

# %%
plot_acf(bike['Count'], lags = 60)
plt.grid()
plt.show()

# %% [markdown]
# ### (2) 패턴을 데이터로 만들기

# %% [markdown]
# #### 1) 날짜 요소 추출

# %% [markdown]
# | 메서드 | 내용|
# |----|----|
# df['date'].dt.date         		| YYYY-MM-DD(문자)
# df['date'].dt.year         		| 연(4자리숫자)
# df['date'].dt.month        		| 월(숫자)
# df['date'].dt.month_name()		| 월(문자)
# df['date'].dt.day          		| 일(숫자)
# df['date'].dt.time         		| HH:MM:SS(문자)
# df['date'].dt.hour         		| 시(숫자)
# df['date'].dt.minute       		| 분(숫자)
# df['date'].dt.second       		| 초(숫자)
# df['date'].dt.quarter       		| 분기(숫자)
# df['date'].dt.day_name()  	| 요일이름(문자)
# df['date'].dt.weekday       		| 요일숫자(0-월, 1-화) (=dayofweek)
# df['date'].dt.weekofyear    		| 연 기준 몇주째(숫자) (=week)
# df['date'].dt.dayofyear     		| 연 기준 몇일째(숫자)
# df['date'].dt.days_in_month 	| 월 일수(숫자) (=daysinmonth)

# %%
temp = bike.copy()

# %% [markdown]
# ① 요일

# %%
temp['Datetime'].dt.weekday
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1507    6
# 1508    6
# 1509    6
# 1510    6
# 1511    6
# Name: Datetime, Length: 1512, dtype: int64

# %%
temp['weekday'] = temp['Datetime'].dt.weekday
temp.head()
# Out:
#              Datetime  Temperature  Humidity  Count  weekday
# 0 2018-06-11 00:00:00         20.3      58.0    918        0
# 1 2018-06-11 01:00:00         19.8      59.0    555        0
# 2 2018-06-11 02:00:00         19.2      60.0    353        0
# 3 2018-06-11 03:00:00         18.8      61.0    232        0
# 4 2018-06-11 04:00:00         18.8      60.0    194        0

# %% [markdown]
# ② 시간대

# %%
temp['hour'] = temp['Datetime'].dt.hour
temp.head()
# Out:
#              Datetime  Temperature  Humidity  Count  weekday  hour
# 0 2018-06-11 00:00:00         20.3      58.0    918        0     0
# 1 2018-06-11 01:00:00         19.8      59.0    555        0     1
# 2 2018-06-11 02:00:00         19.2      60.0    353        0     2
# 3 2018-06-11 03:00:00         18.8      61.0    232        0     3
# 4 2018-06-11 04:00:00         18.8      60.0    194        0     4

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] 위에서 생성한 temp에 다음의 변수를 추가해 봅시다.
#
# * 주말여부
# * 주요 시간대 범주화
#     * 범주 종류 : 0 - 활동 없음, 1 - 일상 활동시간, 2 - 출퇴근
#     * 시간대
#         * 0~6 : 0
#         * 7~8 : 2
#         * 9~16: 1
#         * 17~20 : 2
#         * 21~23 : 0

# %%
# 주말 여부
temp['weekend'] = np.where(temp['weekday'] < 5, 0, 1)
temp.head()
# Out:
#              Datetime  Temperature  Humidity  Count  weekday  hour  weekend
# 0 2018-06-11 00:00:00         20.3      58.0    918        0     0        0
# 1 2018-06-11 01:00:00         19.8      59.0    555        0     1        0
# 2 2018-06-11 02:00:00         19.2      60.0    353        0     2        0
# 3 2018-06-11 03:00:00         18.8      61.0    232        0     3        0
# 4 2018-06-11 04:00:00         18.8      60.0    194        0     4        0

# %%
# 주요 시간대 범주화
temp['Active'] = pd.cut(temp['hour'], bins=[0,6,8,16,20,23], labels = [0,2,1,2,0],
                        ordered = False, include_lowest = True)

# %% [markdown]
# #### 2) 시간의 흐름을 feature로 담기

# %% [markdown]
# ① shift

# %%
temp2 = bike[['Datetime', 'Count']].copy()
temp2.head()
# Out:
#              Datetime  Count
# 0 2018-06-11 00:00:00    918
# 1 2018-06-11 01:00:00    555
# 2 2018-06-11 02:00:00    353
# 3 2018-06-11 03:00:00    232
# 4 2018-06-11 04:00:00    194

# %%
# shift(1)
temp2['lag1'] = temp2['Count'].shift()

# shift(2)
temp2['lag2'] = temp2['Count'].shift(2)

# shift(-1)
temp2['lag_1'] = temp2['Count'].shift(-1)
temp2.head()
# Out:
#              Datetime  Count   lag1   lag2  lag_1
# 0 2018-06-11 00:00:00    918    NaN    NaN  555.0
# 1 2018-06-11 01:00:00    555  918.0    NaN  353.0
# 2 2018-06-11 02:00:00    353  555.0  918.0  232.0
# 3 2018-06-11 03:00:00    232  353.0  555.0  194.0
# 4 2018-06-11 04:00:00    194  232.0  353.0  324.0

# %% [markdown]
# ② rolling

# %%
temp2 = bike[['Datetime', 'Count']].copy()
temp2.head()
# Out:
#              Datetime  Count
# 0 2018-06-11 00:00:00    918
# 1 2018-06-11 01:00:00    555
# 2 2018-06-11 02:00:00    353
# 3 2018-06-11 03:00:00    232
# 4 2018-06-11 04:00:00    194

# %%
# 3일 이동평균
temp2['MA3'] = temp2['Count'].rolling(3).mean()

# 3일 이동최대값
temp2['MM3'] = temp2['Count'].rolling(3).max()

# 3일 이동평균(min_period = 1)
temp2['MA3_1'] = temp2['Count'].rolling(3, min_periods=1).mean()

temp2.head()
# Out:
#              Datetime  Count         MA3    MM3       MA3_1
# 0 2018-06-11 00:00:00    918         NaN    NaN  918.000000
# 1 2018-06-11 01:00:00    555         NaN    NaN  736.500000
# 2 2018-06-11 02:00:00    353  608.666667  918.0  608.666667
# 3 2018-06-11 03:00:00    232  380.000000  555.0  380.000000
# 4 2018-06-11 04:00:00    194  259.666667  353.0  259.666667

# %% [markdown]
# ③ diff : 특정 시점 대비 증감

# %%
temp2 = bike[['Datetime', 'Count']].copy()
temp2.head()
# Out:
#              Datetime  Count
# 0 2018-06-11 00:00:00    918
# 1 2018-06-11 01:00:00    555
# 2 2018-06-11 02:00:00    353
# 3 2018-06-11 03:00:00    232
# 4 2018-06-11 04:00:00    194

# %%
# 전시점대비 증감
temp2['Diff1'] = temp2['Count'].diff()

# 전전시점 대비 증가
temp2['Diff2'] = temp2['Count'].diff(2)

temp2.head()
# Out:
#              Datetime  Count  Diff1  Diff2
# 0 2018-06-11 00:00:00    918    NaN    NaN
# 1 2018-06-11 01:00:00    555 -363.0    NaN
# 2 2018-06-11 02:00:00    353 -202.0 -565.0
# 3 2018-06-11 03:00:00    232 -121.0 -323.0
# 4 2018-06-11 04:00:00    194  -38.0 -159.0

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# [문1] temp에 24시간 전 대여량을 추가하시오.

# %%
temp['lag24'] = temp['Count'].shift(24)
temp.head(30)
# Out:
#               Datetime  Temperature  Humidity  Count  weekday  hour  weekend  \
# 0  2018-06-11 00:00:00         20.3      58.0    918        0     0        0
# 1  2018-06-11 01:00:00         19.8      59.0    555        0     1        0
# 2  2018-06-11 02:00:00         19.2      60.0    353        0     2        0
# 3  2018-06-11 03:00:00         18.8      61.0    232        0     3        0
# 4  2018-06-11 04:00:00         18.8      60.0    194        0     4        0
# 5  2018-06-11 05:00:00         18.8      61.0    324        0     5        0
# 6  2018-06-11 06:00:00         18.6      61.0    807        0     6        0
# 7  2018-06-11 07:00:00         19.1      59.0   1629        0     7        0
# 8  2018-06-11 08:00:00         20.7      55.0   2375        0     8        0
# 9  2018-06-11 09:00:00         22.2      48.0   1307        0     9        0
# 10 2018-06-11 10:00:00         23.7      47.0    992        0    10        0
# 11 2018-06-11 11:00:00         23.2      52.0   1107        0    11        0
# 12 2018-06-11 12:00:00         23.2      52.0   1204        0    12        0
# 13 2018-06-11 13:00:00         23.7      49.0   1033        0    13        0
# 14 2018-06-11 14:00:00         23.9      47.0   1075        0    14        0
# 15 2018-06-11 15:00:00         22.2      60.0   1240        0    15        0
# 16 2018-06-11 16:00:00         22.0      60.0   1220        0    16        0
# 17 2018-06-11 17:00:00         20.7      72.0   1475        0    17        0
# 18 2018-06-11 18:00:00         19.8      80.0   1491        0    18        0
# 19 2018-06-11 19:00:00         19.4      85.0    873        0    19        0
# 20 2018-06-11 20:00:00         19.1      84.0   1280        0    20        0
# 21 2018-06-11 21:00:00         19.0      82.0   1647        0    21        0
# 22 2018-06-11 22:00:00         19.0      76.0   1117        0    22        0
# 23 2018-06-11 23:00:00         18.2      93.0    384        0    23        0
# 24 2018-06-12 00:00:00         18.0      94.0    470        1     0        0
# 25 2018-06-12 01:00:00         17.7      92.0    454        1     1        0
# 26 2018-06-12 02:00:00         17.7      87.0    385        1     2        0
# 27 2018-06-12 03:00:00         17.5      87.0    206        1     3        0
# 28 2018-06-12 04:00:00         17.5      84.0    144        1     4        0
# 29 2018-06-12 05:00:00         17.2      87.0    296        1     5        0
#
#    Active  lag24
# 0       0    NaN
# 1       0    NaN
# 2       0    NaN
# 3       0    NaN
# 4       0    NaN
# 5       0    NaN
# 6       0    NaN
# 7       2    NaN
# 8       2    NaN
# 9       1    NaN
# 10      1    NaN
# 11      1    NaN
# 12      1    NaN
# 13      1    NaN
# 14      1    NaN
# 15      1    NaN
# 16      1    NaN
# 17      2    NaN
# 18      2    NaN
# 19      2    NaN
# 20      2    NaN
# 21      0    NaN
# 22      0    NaN
# 23      0    NaN
# 24      0  918.0
# 25      0  555.0
# 26      0  353.0
# 27      0  232.0
# 28      0  194.0
# 29      0  324.0

# %% [markdown]
# [문2] temp에 4시간 이동평균 대여량을 추가하시오.

# %%
temp['MA4'] = temp['Count'].rolling(4, min_periods = 1).mean()
temp.head(10)
# Out:
#              Datetime  Temperature  Humidity  Count  weekday  hour  weekend  \
# 0 2018-06-11 00:00:00         20.3      58.0    918        0     0        0
# 1 2018-06-11 01:00:00         19.8      59.0    555        0     1        0
# 2 2018-06-11 02:00:00         19.2      60.0    353        0     2        0
# 3 2018-06-11 03:00:00         18.8      61.0    232        0     3        0
# 4 2018-06-11 04:00:00         18.8      60.0    194        0     4        0
# 5 2018-06-11 05:00:00         18.8      61.0    324        0     5        0
# 6 2018-06-11 06:00:00         18.6      61.0    807        0     6        0
# 7 2018-06-11 07:00:00         19.1      59.0   1629        0     7        0
# 8 2018-06-11 08:00:00         20.7      55.0   2375        0     8        0
# 9 2018-06-11 09:00:00         22.2      48.0   1307        0     9        0
#
#   Active  lag24          MA4
# 0      0    NaN   918.000000
# 1      0    NaN   736.500000
# 2      0    NaN   608.666667
# 3      0    NaN   514.500000
# 4      0    NaN   333.500000
# 5      0    NaN   275.750000
# 6      0    NaN   389.250000
# 7      2    NaN   738.500000
# 8      2    NaN  1283.750000
# 9      1    NaN  1529.500000

# %% [markdown]
# [문3] temp에 24시간 전 대비 대여량 증감을 추가하시오.

# %%
temp['Diff24'] = temp['Count'].diff(24)
temp.head(30)
# Out:
#               Datetime  Temperature  Humidity  Count  weekday  hour  weekend  \
# 0  2018-06-11 00:00:00         20.3      58.0    918        0     0        0
# 1  2018-06-11 01:00:00         19.8      59.0    555        0     1        0
# 2  2018-06-11 02:00:00         19.2      60.0    353        0     2        0
# 3  2018-06-11 03:00:00         18.8      61.0    232        0     3        0
# 4  2018-06-11 04:00:00         18.8      60.0    194        0     4        0
# 5  2018-06-11 05:00:00         18.8      61.0    324        0     5        0
# 6  2018-06-11 06:00:00         18.6      61.0    807        0     6        0
# 7  2018-06-11 07:00:00         19.1      59.0   1629        0     7        0
# 8  2018-06-11 08:00:00         20.7      55.0   2375        0     8        0
# 9  2018-06-11 09:00:00         22.2      48.0   1307        0     9        0
# 10 2018-06-11 10:00:00         23.7      47.0    992        0    10        0
# 11 2018-06-11 11:00:00         23.2      52.0   1107        0    11        0
# 12 2018-06-11 12:00:00         23.2      52.0   1204        0    12        0
# 13 2018-06-11 13:00:00         23.7      49.0   1033        0    13        0
# 14 2018-06-11 14:00:00         23.9      47.0   1075        0    14        0
# 15 2018-06-11 15:00:00         22.2      60.0   1240        0    15        0
# 16 2018-06-11 16:00:00         22.0      60.0   1220        0    16        0
# 17 2018-06-11 17:00:00         20.7      72.0   1475        0    17        0
# 18 2018-06-11 18:00:00         19.8      80.0   1491        0    18        0
# 19 2018-06-11 19:00:00         19.4      85.0    873        0    19        0
# 20 2018-06-11 20:00:00         19.1      84.0   1280        0    20        0
# 21 2018-06-11 21:00:00         19.0      82.0   1647        0    21        0
# 22 2018-06-11 22:00:00         19.0      76.0   1117        0    22        0
# 23 2018-06-11 23:00:00         18.2      93.0    384        0    23        0
# 24 2018-06-12 00:00:00         18.0      94.0    470        1     0        0
# 25 2018-06-12 01:00:00         17.7      92.0    454        1     1        0
# 26 2018-06-12 02:00:00         17.7      87.0    385        1     2        0
# 27 2018-06-12 03:00:00         17.5      87.0    206        1     3        0
# 28 2018-06-12 04:00:00         17.5      84.0    144        1     4        0
# 29 2018-06-12 05:00:00         17.2      87.0    296        1     5        0
#
#    Active  lag24          MA4  Diff24
# 0       0    NaN   918.000000     NaN
# 1       0    NaN   736.500000     NaN
# 2       0    NaN   608.666667     NaN
# 3       0    NaN   514.500000     NaN
# 4       0    NaN   333.500000     NaN
# 5       0    NaN   275.750000     NaN
# 6       0    NaN   389.250000     NaN
# 7       2    NaN   738.500000     NaN
# 8       2    NaN  1283.750000     NaN
# 9       1    NaN  1529.500000     NaN
# 10      1    NaN  1575.750000     NaN
# 11      1    NaN  1445.250000     NaN
# 12      1    NaN  1152.500000     NaN
# 13      1    NaN  1084.000000     NaN
# 14      1    NaN  1104.750000     NaN
# 15      1    NaN  1138.000000     NaN
# 16      1    NaN  1142.000000     NaN
# 17      2    NaN  1252.500000     NaN
# 18      2    NaN  1356.500000     NaN
# 19      2    NaN  1264.750000     NaN
# 20      2    NaN  1279.750000     NaN
# 21      0    NaN  1322.750000     NaN
# 22      0    NaN  1229.250000     NaN
# 23      0    NaN  1107.000000     NaN
# 24      0  918.0   904.500000  -448.0
# 25      0  555.0   606.250000  -101.0
# 26      0  353.0   423.250000    32.0
# 27      0  232.0   378.750000   -26.0
# 28      0  194.0   297.250000   -50.0
# 29      0  324.0   257.750000   -28.0

# %% [markdown]
# ### (3) 어떤 패턴도 보이지 않는 y
# * 이전 데이터 대비 증감으로 분석하기

# %%
# 데이터 차분(difference) 데이터를 만들고
kospi['diff'] = kospi['Close'].diff()

# %%
# 그래프를 그리면, 이전과 다른 새로운 관점의 그래프를 얻을 수 있습니다.

plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
sns.histplot(x = 'Close', data = kospi, bins = 50)

plt.subplot(1,2,2)
sns.histplot(x = 'diff', data = kospi, bins = 50)
plt.show()
