# %% [markdown]
# # 이진분류 종합실습 : 이직 예측

# %% [markdown]
# * 회사 인사팀에서는 AIVLER 들에게 직원의 이직여부과 관련해서 분석을 요청하였습니다.
# * 최근 이직율이 증가하는 것에 대해 우려를 갖고 있기에, 이직여부에 영향을 주는 요인에 대해 분석하여, 이직할 것으로 보이는 직원들에 대해 회사를 떠나지 않도록 인사 프로그램을 준비하려고 합니다.
# * 어떤 직원이 이직할지 예측해 봅시다.

# %% [markdown]
# ![](https://adoptostaging.blob.core.windows.net/media/employee-attrition-reasons-9LIqMv.jpg)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Input
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_train_validation.CSV"
data = pd.read_csv(path)
data['Attrition'] = np.where(data['Attrition']=='Yes', 1, 0)
data.head(10)
# Out:
#    Attrition  Age     BusinessTravel              Department  \
# 0          0   33      Travel_Rarely  Research & Development
# 1          0   35  Travel_Frequently  Research & Development
# 2          0   42      Travel_Rarely  Research & Development
# 3          0   46      Travel_Rarely                   Sales
# 4          0   39  Travel_Frequently                   Sales
# 5          1   22  Travel_Frequently  Research & Development
# 6          0   24      Travel_Rarely  Research & Development
# 7          0   34      Travel_Rarely  Research & Development
# 8          0   30      Travel_Rarely  Research & Development
# 9          0   26      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                 7          3           Medical             817
# 1                18          2     Life Sciences            1412
# 2                 6          3           Medical            1911
# 3                 2          3         Marketing            1204
# 4                20          3     Life Sciences            1812
# 5                 4          1  Technical Degree             593
# 6                21          2  Technical Degree            1551
# 7                 8          3           Medical            2068
# 8                20          3             Other            1084
# 9                 6          3     Life Sciences             686
#
#    EnvironmentSatisfaction  Gender  ...  OverTime PercentSalaryHike  \
# 0                        3    Male  ...        No                11
# 1                        3    Male  ...        No                11
# 2                        3    Male  ...        No                13
# 3                        3  Female  ...        No                23
# 4                        3    Male  ...        No                18
# 5                        3    Male  ...        No                16
# 6                        3    Male  ...        No                14
# 7                        2    Male  ...        No                12
# 8                        3    Male  ...        No                15
# 9                        3  Female  ...       Yes                13
#
#    RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0                         4                0                 14
# 1                         3                0                 10
# 2                         2                1                 18
# 3                         1                0                 28
# 4                         4                1                  7
# 5                         3                0                  4
# 6                         2                3                  2
# 7                         1                0                  6
# 8                         3                1                  7
# 9                         3                1                  3
#
#    TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      3               4              13                   9
# 1                      2               3               2                   2
# 2                      3               4              13                   7
# 3                      2               3              26                  15
# 4                      6               3               2                   1
# 5                      3               3               2                   2
# 6                      3               3               1                   1
# 7                      3               4               4                   3
# 8                      1               2               6                   2
# 9                      2               3               3                   2
#
#    YearsWithCurrManager
# 0                     7
# 1                     2
# 2                     7
# 3                     9
# 4                     2
# 5                     2
# 6                     0
# 7                     2
# 8                     2
# 9                     2
#
# [10 rows x 26 columns]

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EmployeeNumber	|	사번	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	| Single, Married, Divorced		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	OverTime	|	야근여부	|	범주	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %% [markdown]
# ----

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# ### (1) 데이터 정리

# %%
target = 'Attrition'

# %%
# 불필요한 변수 제거
data.drop('EmployeeNumber', axis = 1, inplace = True)

# %%
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화
# * 범주형 데이터이면서 값이 0,1 로 되어 있는 것이 아니라면, 가변수화를 수행해야 합니다.
# * 대상이 되는 변수에 대해서 가변수화를 수행해주세요.

# %%
dum_cols = ['BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender',
            'JobRole', 'JobInvolvement', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction',
            'StockOptionLevel','WorkLifeBalance' ]

x = pd.get_dummies(x, columns = dum_cols ,drop_first = True)
x.head()
# Out:
#    Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0   33                 7          11691                   0
# 1   35                18           9362                   2
# 2   42                 6          13348                   9
# 3   46                 2          17048                   8
# 4   39                20           4127                   2
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11                 14                      3
# 1                 11                 10                      2
# 2                 13                 18                      3
# 3                 23                 28                      2
# 4                 18                  7                      6
#
#    YearsAtCompany  YearsInCurrentRole  YearsWithCurrManager  ...  \
# 0              13                   9                     7  ...
# 1               2                   2                     2  ...
# 2              13                   7                     7  ...
# 3              26                  15                     9  ...
# 4               2                   1                     2  ...
#
#    OverTime_Yes  RelationshipSatisfaction_2  RelationshipSatisfaction_3  \
# 0         False                       False                       False
# 1         False                       False                        True
# 2         False                        True                       False
# 3         False                       False                       False
# 4         False                       False                       False
#
#    RelationshipSatisfaction_4  StockOptionLevel_1  StockOptionLevel_2  \
# 0                        True               False               False
# 1                       False               False               False
# 2                       False                True               False
# 3                       False               False               False
# 4                        True                True               False
#
#    StockOptionLevel_3  WorkLifeBalance_2  WorkLifeBalance_3  WorkLifeBalance_4
# 0               False              False              False               True
# 1               False              False               True              False
# 2               False              False              False               True
# 3               False              False               True              False
# 4               False              False               True              False
#
# [5 rows x 53 columns]

# %% [markdown]
# ### (3) 데이터 분할
# * train_test_split :
#     * test_size : 0.# - 비율로 분할, 1보다 큰 자연수 - 갯수로 분할
#     * train_size로 지정도 가능.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 200, random_state = 2022)

# %% [markdown]
# ### (4) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %%
y_train.value_counts() / len(y_train)
# Out:
# Attrition
# 0    0.839048
# 1    0.160952
# Name: count, dtype: float64

# %% [markdown]
# ## 4.모델링

# %% [markdown]
# ### (1) 모델1
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
n = x_train.shape[1]
n
# Out:
# 53

# %%
clear_session()

model = Sequential([Input(shape = (nfeatures,)),
                    Dense( 16, activation = 'relu' ),
                    Dense( 8 , activation = 'relu' ),
                    Dense( 4 , activation = 'relu'),
                    Dense( 1 , activation= 'sigmoid')])
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,041 (4.07 KB)
#  Trainable params: 1,041 (4.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile( optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
hist = model.fit( x_train, y_train, epochs = 50, validation_split= .2 ).history
# Out:
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - loss: 0.7453 - val_loss: 0.6933
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6863 - val_loss: 0.6771
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6754 - val_loss: 0.6680
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6661 - val_loss: 0.6593
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6573 - val_loss: 0.6512
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6502 - val_loss: 0.6433
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6433 - val_loss: 0.6359
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6363 - val_loss: 0.6286
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6289 - val_loss: 0.6206
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6193 - val_loss: 0.6035
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5969 - val_loss: 0.5391
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5105 - val_loss: 0.4389
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4192 - val_loss: 0.4098
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4286 - val_loss: 0.4004
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3688 - val_loss: 0.3903
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4035 - val_loss: 0.3811
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3727 - val_loss: 0.3668
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3456 - val_loss: 0.3561
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3376 - val_loss: 0.3514
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3238 - val_loss: 0.3422
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2986 - val_loss: 0.3431
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2944 - val_loss: 0.3424
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2842 - val_loss: 0.3451
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2731 - val_loss: 0.3487
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2610 - val_loss: 0.3547
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2742 - val_loss: 0.3386
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2812 - val_loss: 0.3335
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2839 - val_loss: 0.3430
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2681 - val_loss: 0.3408
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2310 - val_loss: 0.3591
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2347 - val_loss: 0.3684
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2186 - val_loss: 0.3486
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2173 - val_loss: 0.3752
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2552 - val_loss: 0.3613
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2446 - val_loss: 0.3424
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2332 - val_loss: 0.3508
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2480 - val_loss: 0.3544
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2119 - val_loss: 0.3443
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2319 - val_loss: 0.3482
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2452 - val_loss: 0.3439
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2249 - val_loss: 0.3747
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2054 - val_loss: 0.3689
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2214 - val_loss: 0.3660
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2209 - val_loss: 0.3948
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2338 - val_loss: 0.3538
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2193 - val_loss: 0.3729
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1874 - val_loss: 0.3921
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1847 - val_loss: 0.3776
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1940 - val_loss: 0.3618
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2018 - val_loss: 0.3802

# %%
dl_history_plot(hist)

# %%
pred = model.predict(x_val)
pred = np.where( pred >= 0.5 , 1 , 0)

print(confusion_matrix(y_val, pred))
print(classification_report(y_val, pred))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# [[158  11]
#  [ 15  16]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       169
#            1       0.59      0.52      0.55        31
#
#     accuracy                           0.87       200
#    macro avg       0.75      0.73      0.74       200
# weighted avg       0.86      0.87      0.87       200

# %% [markdown]
# ### (2) 모델2
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
n = x_train.shape[1]
n
# Out:
# 53

# %%
clear_session()

model = Sequential([Input(shape = (nfeatures,)),
                    Dense( 16, activation = 'relu' ),
                    Dense( 8 ,  activation = 'relu' ),
                    Dense( 4 ,  activation = 'relu'),
                    Dense( 1 , activation= 'sigmoid')])
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,041 (4.07 KB)
#  Trainable params: 1,041 (4.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile( optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
hist = model.fit( x_train, y_train, epochs = 50, validation_split= .2 ).history
# Out:
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.7167 - val_loss: 0.6855
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6822 - val_loss: 0.6723
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6675 - val_loss: 0.6444
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6361 - val_loss: 0.5862
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5676 - val_loss: 0.4825
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4824 - val_loss: 0.4152
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4270 - val_loss: 0.4042
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4251 - val_loss: 0.3997
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3986 - val_loss: 0.3965
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4202 - val_loss: 0.3919
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3761 - val_loss: 0.3874
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4069 - val_loss: 0.3830
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3981 - val_loss: 0.3793
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3796 - val_loss: 0.3752
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3821 - val_loss: 0.3704
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3694 - val_loss: 0.3658
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3551 - val_loss: 0.3613
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3461 - val_loss: 0.3555
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3648 - val_loss: 0.3512
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3584 - val_loss: 0.3479
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3170 - val_loss: 0.3474
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3354 - val_loss: 0.3448
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3352 - val_loss: 0.3430
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3296 - val_loss: 0.3433
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3175 - val_loss: 0.3415
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2859 - val_loss: 0.3445
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3106 - val_loss: 0.3376
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3206 - val_loss: 0.3359
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3014 - val_loss: 0.3406
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2936 - val_loss: 0.3343
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3068 - val_loss: 0.3378
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2872 - val_loss: 0.3370
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2351 - val_loss: 0.3390
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2639 - val_loss: 0.3437
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2705 - val_loss: 0.3355
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2595 - val_loss: 0.3390
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2960 - val_loss: 0.3375
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2816 - val_loss: 0.3437
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2641 - val_loss: 0.3396
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2684 - val_loss: 0.3383
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2486 - val_loss: 0.3381
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2519 - val_loss: 0.3373
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2829 - val_loss: 0.3383
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2340 - val_loss: 0.3504
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2408 - val_loss: 0.3384
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2405 - val_loss: 0.3415
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2274 - val_loss: 0.3455
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2575 - val_loss: 0.3429
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2635 - val_loss: 0.3378
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2350 - val_loss: 0.3426

# %%
dl_history_plot(hist)

# %%
pred = model.predict(x_val)
pred = np.where( pred >= 0.5 , 1 , 0)

print(confusion_matrix(y_val, pred))
print(classification_report(y_val, pred))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# [[163   6]
#  [ 14  17]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       169
#            1       0.74      0.55      0.63        31
#
#     accuracy                           0.90       200
#    macro avg       0.83      0.76      0.79       200
# weighted avg       0.89      0.90      0.89       200

# %% [markdown]
# ### (3) 모델3 : resampling

# %%
y_train.value_counts()
# Out:
# Attrition
# 0    881
# 1    169
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler()
x_train_ros, y_train_ros = ros.fit_resample(x_train, y_train)

# %%
n = x_train.shape[1]
n
# Out:
# 53

# %%
clear_session()

model2 = Sequential([Input(shape = (nfeatures,)),
                     Dense( 16, activation = 'relu' ),
                    Dense( 8 ,  activation = 'relu' ),
                    Dense( 4 ,  activation = 'relu'),
                    Dense( 1 , activation= 'sigmoid')])
model2.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,041 (4.07 KB)
#  Trainable params: 1,041 (4.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model2.compile( optimizer = Adam(learning_rate = 0.001), loss = 'binary_crossentropy')
hist = model2.fit( x_train_ros, y_train_ros, epochs = 150, validation_split= .2 ).history
# Out:
# Epoch 1/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.6815 - val_loss: 0.8261
# Epoch 2/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6593 - val_loss: 0.9188
# Epoch 3/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6382 - val_loss: 0.9646
# Epoch 4/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6267 - val_loss: 0.9814
# Epoch 5/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5956 - val_loss: 0.9530
# Epoch 6/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5757 - val_loss: 0.9212
# Epoch 7/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5503 - val_loss: 0.8919
# Epoch 8/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5305 - val_loss: 0.8385
# Epoch 9/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4739 - val_loss: 0.7407
# Epoch 10/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4651 - val_loss: 0.6211
# Epoch 11/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4377 - val_loss: 0.6086
# Epoch 12/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4143 - val_loss: 0.5998
# Epoch 13/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4269 - val_loss: 0.7346
# Epoch 14/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3965 - val_loss: 0.5918
# Epoch 15/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3861 - val_loss: 0.5821
# Epoch 16/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3788 - val_loss: 0.5968
# Epoch 17/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3433 - val_loss: 0.5470
# Epoch 18/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3402 - val_loss: 0.5058
# Epoch 19/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3528 - val_loss: 0.4943
# Epoch 20/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3548 - val_loss: 0.4767
# Epoch 21/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3386 - val_loss: 0.5165
# Epoch 22/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3204 - val_loss: 0.5368
# Epoch 23/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3449 - val_loss: 0.4401
# Epoch 24/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3287 - val_loss: 0.4414
# Epoch 25/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2974 - val_loss: 0.4964
# Epoch 26/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3115 - val_loss: 0.4113
# Epoch 27/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2948 - val_loss: 0.5369
# Epoch 28/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3087 - val_loss: 0.4387
# Epoch 29/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2919 - val_loss: 0.4714
# Epoch 30/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2767 - val_loss: 0.3590
# Epoch 31/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2966 - val_loss: 0.4585
# Epoch 32/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2822 - val_loss: 0.5280
# Epoch 33/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2817 - val_loss: 0.4308
# Epoch 34/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2734 - val_loss: 0.4251
# Epoch 35/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2478 - val_loss: 0.4883
# Epoch 36/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2566 - val_loss: 0.4354
# Epoch 37/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2658 - val_loss: 0.3951
# Epoch 38/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2524 - val_loss: 0.4461
# Epoch 39/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2470 - val_loss: 0.4012
# Epoch 40/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2296 - val_loss: 0.4085
# Epoch 41/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2316 - val_loss: 0.3371
# Epoch 42/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2270 - val_loss: 0.3516
# Epoch 43/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2124 - val_loss: 0.3023
# Epoch 44/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2092 - val_loss: 0.3628
# Epoch 45/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2060 - val_loss: 0.3428
# Epoch 46/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2068 - val_loss: 0.2933
# Epoch 47/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2095 - val_loss: 0.2942
# Epoch 48/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2072 - val_loss: 0.2557
# Epoch 49/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2027 - val_loss: 0.3180
# Epoch 50/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2067 - val_loss: 0.3237
# Epoch 51/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1983 - val_loss: 0.2910
# Epoch 52/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2004 - val_loss: 0.2922
# Epoch 53/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1569 - val_loss: 0.3258
# Epoch 54/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1746 - val_loss: 0.2969
# Epoch 55/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1696 - val_loss: 0.2037
# Epoch 56/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1698 - val_loss: 0.3974
# Epoch 57/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1678 - val_loss: 0.2981
# Epoch 58/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1515 - val_loss: 0.3337
# Epoch 59/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1794 - val_loss: 0.2566
# Epoch 60/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1501 - val_loss: 0.2779
# Epoch 61/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1446 - val_loss: 0.2646
# Epoch 62/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1385 - val_loss: 0.2827
# Epoch 63/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1541 - val_loss: 0.2154
# Epoch 64/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1543 - val_loss: 0.2679
# Epoch 65/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1289 - val_loss: 0.1930
# Epoch 66/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1312 - val_loss: 0.2575
# Epoch 67/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1318 - val_loss: 0.1948
# Epoch 68/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1268 - val_loss: 0.2180
# Epoch 69/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1353 - val_loss: 0.2877
# Epoch 70/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1441 - val_loss: 0.2139
# Epoch 71/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1161 - val_loss: 0.1811
# Epoch 72/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1108 - val_loss: 0.1898
# Epoch 73/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1129 - val_loss: 0.2032
# Epoch 74/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1152 - val_loss: 0.2207
# Epoch 75/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1119 - val_loss: 0.1682
# Epoch 76/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1160 - val_loss: 0.1862
# Epoch 77/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1097 - val_loss: 0.1706
# Epoch 78/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1119 - val_loss: 0.1541
# Epoch 79/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0970 - val_loss: 0.1842
# Epoch 80/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0900 - val_loss: 0.1650
# Epoch 81/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0928 - val_loss: 0.1584
# Epoch 82/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0975 - val_loss: 0.2044
# Epoch 83/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1370 - val_loss: 0.2219
# Epoch 84/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1065 - val_loss: 0.1434
# Epoch 85/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0813 - val_loss: 0.1610
# Epoch 86/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0776 - val_loss: 0.1624
# Epoch 87/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0962 - val_loss: 0.1649
# Epoch 88/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0914 - val_loss: 0.1563
# Epoch 89/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0833 - val_loss: 0.1553
# Epoch 90/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0796 - val_loss: 0.1459
# Epoch 91/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0781 - val_loss: 0.1697
# Epoch 92/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0763 - val_loss: 0.1580
# Epoch 93/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0658 - val_loss: 0.1294
# Epoch 94/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0764 - val_loss: 0.1614
# Epoch 95/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0809 - val_loss: 0.1238
# Epoch 96/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0653 - val_loss: 0.1692
# Epoch 97/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1123 - val_loss: 0.1311
# Epoch 98/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0774 - val_loss: 0.1627
# Epoch 99/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0726 - val_loss: 0.1617
# Epoch 100/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0544 - val_loss: 0.1397
# Epoch 101/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0755 - val_loss: 0.1224
# Epoch 102/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0713 - val_loss: 0.1107
# Epoch 103/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0650 - val_loss: 0.1261
# Epoch 104/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - val_loss: 0.1179
# Epoch 105/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0608 - val_loss: 0.1279
# Epoch 106/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0688 - val_loss: 0.1324
# Epoch 107/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - val_loss: 0.1035
# Epoch 108/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0521 - val_loss: 0.1120
# Epoch 109/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0664 - val_loss: 0.1045
# Epoch 110/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0600 - val_loss: 0.1138
# Epoch 111/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0659 - val_loss: 0.1013
# Epoch 112/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458 - val_loss: 0.1070
# Epoch 113/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0494 - val_loss: 0.0966
# Epoch 114/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0438 - val_loss: 0.0983
# Epoch 115/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0479 - val_loss: 0.0933
# Epoch 116/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0403 - val_loss: 0.1035
# Epoch 117/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - val_loss: 0.1034
# Epoch 118/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0399 - val_loss: 0.0855
# Epoch 119/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452 - val_loss: 0.0875
# Epoch 120/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0485 - val_loss: 0.0994
# Epoch 121/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - val_loss: 0.0694
# Epoch 122/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0711 - val_loss: 0.0772
# Epoch 123/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - val_loss: 0.0775
# Epoch 124/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400 - val_loss: 0.0799
# Epoch 125/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0305 - val_loss: 0.0925
# Epoch 126/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0344 - val_loss: 0.0870
# Epoch 127/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0606 - val_loss: 0.0797
# Epoch 128/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0334 - val_loss: 0.0762
# Epoch 129/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0427 - val_loss: 0.0791
# Epoch 130/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0415 - val_loss: 0.1047
# Epoch 131/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0342 - val_loss: 0.0810
# Epoch 132/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0387 - val_loss: 0.0618
# Epoch 133/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0302 - val_loss: 0.0638
# Epoch 134/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0406 - val_loss: 0.0881
# Epoch 135/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0398 - val_loss: 0.0732
# Epoch 136/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - val_loss: 0.0686
# Epoch 137/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - val_loss: 0.0644
# Epoch 138/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0301 - val_loss: 0.0752
# Epoch 139/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0443 - val_loss: 0.1586
# Epoch 140/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1570 - val_loss: 0.0814
# Epoch 141/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0704 - val_loss: 0.0835
# Epoch 142/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0412 - val_loss: 0.0755
# Epoch 143/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0335 - val_loss: 0.0655
# Epoch 144/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.0600
# Epoch 145/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0296 - val_loss: 0.0695
# Epoch 146/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - val_loss: 0.0661
# Epoch 147/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0303 - val_loss: 0.0594
# Epoch 148/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - val_loss: 0.0568
# Epoch 149/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195 - val_loss: 0.0611
# Epoch 150/150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0338 - val_loss: 0.0593

# %%
dl_history_plot(hist)

# %%
pred = model2.predict(x_val)
pred = np.where( pred >= 0.5 , 1 , 0)

print(confusion_matrix(y_val, pred))
print(classification_report(y_val, pred))
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7be9b48d0280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# [[151  18]
#  [ 12  19]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       169
#            1       0.51      0.61      0.56        31
#
#     accuracy                           0.85       200
#    macro avg       0.72      0.75      0.73       200
# weighted avg       0.86      0.85      0.86       200
