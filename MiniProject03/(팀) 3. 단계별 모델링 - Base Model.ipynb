# %% [markdown]
# #**스마트폰 센서 데이터 기반 모션 분류**
# # 단계3 : 단계별 모델링

# %% [markdown]
# ## 0.미션4

# %% [markdown]
# * 단계별로 나눠서 모델링을 수행하고자 합니다.
# * 단계 구분 예시
#     * 단계1 : 정적(0), 동적(1) 행동 분류 모델 생성
#     * 단계2 : 세부 동작에 대한 분류모델 생성
#         * 단계1 모델에서 0으로 예측 -> 정적 행동 3가지 분류 모델링
#         * 단계1 모델에서 1으로 예측 -> 동적 행동 3가지 분류 모델링
# * 모델 통합
#     * 두 단계 모델을 통합하고, 새로운 데이터에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
# * 성능 비교
#     * 기본 모델링의 성능과 비교
#     * 성능 가이드
#         * Accuracy : 0.97 ~ 0.99
# * 파이프라인 구성
#     * test 데이터를 입력하여, 전처리 및 예측결과가 나오도록 함수 구성

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project3 폴더를 만들고,
#         * 데이터 파일을 복사해 넣습니다.
#     - 기본적으로 필요한 라이브러리를 import 하도록 코드가 작성되어 있습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project3/'

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU is set to use")
else:
    print("No GPU found")
# Out:
# GPU is set to use

# %% [markdown]
# ### (2) 라이브러리 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import *

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.backend import clear_session
from keras.optimizers import Adam

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (3) 데이터 불러오기

# %% [markdown]
# * 주어진 데이터셋
#     * data01_train.csv : 학습 및 검증용
#     * data01_test.csv : 테스트용
#     * feature.csv : feature 이름을 계층구조로 정리한 데이터
#
# * 세부 요구사항
#     * 칼럼 삭제 : data01_train.csv와 data01_test.csv 에서 'subject' 칼럼은 불필요하므로 삭제합니다.

# %% [markdown]
# #### 1) 데이터로딩

# %%
traindata = pd.read_csv(path + 'data01_train.csv')
traindata = traindata.drop(columns='subject')
traindata.head()
traindata.shape
# Out:
# (5881, 562)

# %%
testdata = pd.read_csv(path + 'data01_test.csv')
testdata = testdata.drop(columns='subject')
testdata.head()
testdata.shape
# Out:
# (1471, 562)

# %%
featuresdata = pd.read_csv(path + 'features.csv')
featuresdata.head()
# Out:
#      sensor     agg axis       feature_name
# 0  tBodyAcc  mean()    X  tBodyAcc-mean()-X
# 1  tBodyAcc  mean()    Y  tBodyAcc-mean()-Y
# 2  tBodyAcc  mean()    Z  tBodyAcc-mean()-Z
# 3  tBodyAcc   std()    X   tBodyAcc-std()-X
# 4  tBodyAcc   std()    Y   tBodyAcc-std()-Y

# %% [markdown]
# #### 2) 기본 정보 조회

# %%
traindata.shape
# Out:
# (5881, 562)

# %%
missing_values = traindata.isna().sum()
missing_values = missing_values[missing_values > 0]
print(missing_values)
# Out:
# Series([], dtype: int64)

# %%
categorical_columns = traindata.select_dtypes(include=['object']).columns
numerical_columns = traindata.select_dtypes(include=['number']).columns
print("Categorical columns:", len(categorical_columns))
print("Numerical columns:", len(numerical_columns))
# Out:
# Categorical columns: 1
# Numerical columns: 561

# %%
target=traindata['Activity']
target.value_counts()
# Out:
# Activity
# LAYING                1115
# STANDING              1087
# SITTING               1032
# WALKING                998
# WALKING_UPSTAIRS       858
# WALKING_DOWNSTAIRS     791
# Name: count, dtype: int64

# %%
testdata['Activity'].value_counts()
# Out:
# Activity
# LAYING                292
# STANDING              287
# SITTING               254
# WALKING               228
# WALKING_UPSTAIRS      215
# WALKING_DOWNSTAIRS    195
# Name: count, dtype: int64

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# * 세부 요구사항
#     - Label 추가 : 1단계 모델을 위한 레이블 추가
#     - train : val = 8 : 2 혹은 7 : 3
#     - random_state 옵션을 사용하여 다른 모델과 비교를 위해 성능이 재현되도록 합니다.

# %% [markdown]
# ### (1) 1단계 모델링을 위한 레이블

# %%
traindata['is_dynamic']=np.where(traindata['Activity'].isin(['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS']),1,0)
testdata['is_dynamic']=np.where(testdata['Activity'].isin(['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS']),1,0)

# %% [markdown]
# ### (2) x, y 분리

# %%
x=traindata.drop(columns=['Activity','is_dynamic'])
y=traindata['is_dynamic']

x_test=testdata.drop(columns=['Activity','is_dynamic'])
y_test=testdata['is_dynamic']

# %% [markdown]
# ### (3) 스케일링

# %% [markdown]
# * 세부 요구사항
#     - 스케일링을 필요로 하는 알고리즘 사용을 위해서 코드 수행
#     - min-max 방식 혹은 standard 방식 중 한가지 사용.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled_test=scaler.transform(x_test)

# 스케일러 저장
joblib.dump(scaler, path+'scaler.pkl')
# Out:
# ['/content/drive/MyDrive/project3/scaler.pkl']

# %% [markdown]
# ### (4) 데이터 분할
# * train, val 분할

# %%
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x_scaled,y,test_size=0.2,stratify=y,random_state=42)

# %% [markdown]
# ## **3.단계별 모델링**

# %% [markdown]
# ### (1) 단계1

# %% [markdown]
# * 세부 요구사항
#     * 적절한 단계로 구분한 후, 1단계를 분류하는 모델 생성
#         * 예시 : 정적 행동(Laying, Sitting, Standing)과 동적 행동(동적 : Walking, Walking-Up, Walking-Down)을 구분하는 모델 생성.
#     * 몇 가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %% [markdown]
# #### 1) 모델1

# %%
import tensorflow as tf, random, numpy as np, pickle

seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)


input_layer=tf.keras.layers.Input(shape=(x_train.shape[1],))
dense_1=tf.keras.layers.Dense(128,activation='relu')(input_layer)
dense_2=tf.keras.layers.Dense(32,activation='relu')(dense_1)
output_layer=tf.keras.layers.Dense(1,activation='sigmoid')(dense_2)
model=tf.keras.models.Model(inputs=input_layer,outputs=output_layer)

optimzers=tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimzers,loss='binary_crossentropy',metrics=['accuracy'])

er=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True)
cl=[er]

history=model.fit(x_train,y_train,validation_split=0.2,epochs=100,callbacks=cl)

dl_history_plot(history.history)

with open(path+'1_step_model_history.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
model.save(path+'1_step_model.keras')



from tensorflow.keras.models import load_model
model=load_model(path+'1_step_model.keras')

with open(path+'1_step_model_history.pkl', 'rb') as file:
    history = pickle.load(file)

dl_history_plot(history)

pred=model.predict(x_val)
pred=np.where(pred>0.5,1,0)
print(confusion_matrix(y_val,pred))
print(classification_report(y_val,pred))
print(accuracy_score(y_val,pred))


pred=model.predict(x_scaled_test)
pred=np.where(pred>0.5,1,0)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
print(accuracy_score(y_test,pred))
# Out:
# Epoch 1/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.9549 - loss: 0.0746 - val_accuracy: 1.0000 - val_loss: 9.6788e-04
# Epoch 2/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7871e-04 - val_accuracy: 1.0000 - val_loss: 1.8346e-04
# Epoch 3/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0144e-04 - val_accuracy: 1.0000 - val_loss: 1.0923e-04
# Epoch 4/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.3294e-05 - val_accuracy: 1.0000 - val_loss: 7.5461e-05
# Epoch 5/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.2680e-05 - val_accuracy: 1.0000 - val_loss: 5.5888e-05
# Epoch 6/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.1093e-05 - val_accuracy: 1.0000 - val_loss: 4.3103e-05
# Epoch 7/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.3691e-05 - val_accuracy: 1.0000 - val_loss: 3.4428e-05
# Epoch 8/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8576e-05 - val_accuracy: 1.0000 - val_loss: 2.8105e-05
# Epoch 9/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4983e-05 - val_accuracy: 1.0000 - val_loss: 2.3308e-05
# Epoch 10/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.2442e-05 - val_accuracy: 1.0000 - val_loss: 1.9681e-05
# Epoch 11/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0393e-05 - val_accuracy: 1.0000 - val_loss: 1.6758e-05
# Epoch 12/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.7857e-06 - val_accuracy: 1.0000 - val_loss: 1.4467e-05
# Epoch 13/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.5094e-06 - val_accuracy: 1.0000 - val_loss: 1.2542e-05
# Epoch 14/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.4367e-06 - val_accuracy: 1.0000 - val_loss: 1.0948e-05
# Epoch 15/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5856e-06 - val_accuracy: 1.0000 - val_loss: 9.5840e-06
# Epoch 16/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.8817e-06 - val_accuracy: 1.0000 - val_loss: 8.4604e-06
# Epoch 17/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.2845e-06 - val_accuracy: 1.0000 - val_loss: 7.4821e-06
# Epoch 18/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.7604e-06 - val_accuracy: 1.0000 - val_loss: 6.6225e-06
# Epoch 19/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.3024e-06 - val_accuracy: 1.0000 - val_loss: 5.9103e-06
# Epoch 20/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.9194e-06 - val_accuracy: 1.0000 - val_loss: 5.2652e-06
# Epoch 21/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.5878e-06 - val_accuracy: 1.0000 - val_loss: 4.7258e-06
# Epoch 22/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.3101e-06 - val_accuracy: 1.0000 - val_loss: 4.2488e-06
# Epoch 23/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.0590e-06 - val_accuracy: 1.0000 - val_loss: 3.8279e-06
# Epoch 24/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.8443e-06 - val_accuracy: 1.0000 - val_loss: 3.4660e-06
# Epoch 25/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.6590e-06 - val_accuracy: 1.0000 - val_loss: 3.1437e-06
# Epoch 26/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4923e-06 - val_accuracy: 1.0000 - val_loss: 2.8634e-06
# Epoch 27/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.3442e-06 - val_accuracy: 1.0000 - val_loss: 2.6160e-06
# Epoch 28/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2206e-06 - val_accuracy: 1.0000 - val_loss: 2.3876e-06
# Epoch 29/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1063e-06 - val_accuracy: 1.0000 - val_loss: 2.1877e-06
# Epoch 30/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.0028e-06 - val_accuracy: 1.0000 - val_loss: 2.0076e-06
# Epoch 31/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.1147e-07 - val_accuracy: 1.0000 - val_loss: 1.8478e-06
# Epoch 32/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.2892e-07 - val_accuracy: 1.0000 - val_loss: 1.6960e-06
# Epoch 33/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.5473e-07 - val_accuracy: 1.0000 - val_loss: 1.5637e-06
# Epoch 34/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.8601e-07 - val_accuracy: 1.0000 - val_loss: 1.4382e-06
# Epoch 35/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.2621e-07 - val_accuracy: 1.0000 - val_loss: 1.3246e-06
# Epoch 36/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.7082e-07 - val_accuracy: 1.0000 - val_loss: 1.2186e-06
# Epoch 37/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.2177e-07 - val_accuracy: 1.0000 - val_loss: 1.1218e-06
# Epoch 38/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.7635e-07 - val_accuracy: 1.0000 - val_loss: 1.0336e-06
# Epoch 39/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.3550e-07 - val_accuracy: 1.0000 - val_loss: 9.5425e-07
# Epoch 40/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.9876e-07 - val_accuracy: 1.0000 - val_loss: 8.8251e-07
# Epoch 41/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.6510e-07 - val_accuracy: 1.0000 - val_loss: 8.1617e-07
# Epoch 42/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3474e-07 - val_accuracy: 1.0000 - val_loss: 7.5579e-07
# Epoch 43/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.0767e-07 - val_accuracy: 1.0000 - val_loss: 6.9952e-07
# Epoch 44/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.8303e-07 - val_accuracy: 1.0000 - val_loss: 6.4903e-07
# Epoch 45/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.6023e-07 - val_accuracy: 1.0000 - val_loss: 6.0374e-07
# Epoch 46/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.3917e-07 - val_accuracy: 1.0000 - val_loss: 5.5996e-07
# Epoch 47/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.2034e-07 - val_accuracy: 1.0000 - val_loss: 5.2061e-07
# Epoch 48/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.0292e-07 - val_accuracy: 1.0000 - val_loss: 4.8388e-07
# Epoch 49/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.8714e-07 - val_accuracy: 1.0000 - val_loss: 4.4968e-07
# Epoch 50/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.7275e-07 - val_accuracy: 1.0000 - val_loss: 4.1894e-07
# Epoch 51/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5961e-07 - val_accuracy: 1.0000 - val_loss: 3.9079e-07
# Epoch 52/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4744e-07 - val_accuracy: 1.0000 - val_loss: 3.6421e-07
# Epoch 53/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3639e-07 - val_accuracy: 1.0000 - val_loss: 3.3905e-07
# Epoch 54/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.2627e-07 - val_accuracy: 1.0000 - val_loss: 3.1639e-07
# Epoch 55/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1700e-07 - val_accuracy: 1.0000 - val_loss: 2.9523e-07
# Epoch 56/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.0845e-07 - val_accuracy: 1.0000 - val_loss: 2.7530e-07
# Epoch 57/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.0061e-07 - val_accuracy: 1.0000 - val_loss: 2.5748e-07
# Epoch 58/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 9.3294e-08 - val_accuracy: 1.0000 - val_loss: 2.4039e-07
# Epoch 59/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.6594e-08 - val_accuracy: 1.0000 - val_loss: 2.2467e-07
# Epoch 60/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.0423e-08 - val_accuracy: 1.0000 - val_loss: 2.1002e-07
# Epoch 61/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.4659e-08 - val_accuracy: 1.0000 - val_loss: 1.9650e-07
# Epoch 62/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.9339e-08 - val_accuracy: 1.0000 - val_loss: 1.8389e-07
# Epoch 63/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.4414e-08 - val_accuracy: 1.0000 - val_loss: 1.7203e-07
# Epoch 64/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.9876e-08 - val_accuracy: 1.0000 - val_loss: 1.6104e-07
# Epoch 65/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 5.5651e-08 - val_accuracy: 1.0000 - val_loss: 1.5080e-07
# Epoch 66/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.1762e-08 - val_accuracy: 1.0000 - val_loss: 1.4114e-07
# Epoch 67/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.8137e-08 - val_accuracy: 1.0000 - val_loss: 1.3228e-07
# Epoch 68/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.4775e-08 - val_accuracy: 1.0000 - val_loss: 1.2389e-07
# Epoch 69/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.1686e-08 - val_accuracy: 1.0000 - val_loss: 1.1620e-07
# Epoch 70/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.8792e-08 - val_accuracy: 1.0000 - val_loss: 1.0888e-07
# Epoch 71/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.6135e-08 - val_accuracy: 1.0000 - val_loss: 1.0207e-07
# Epoch 72/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3658e-08 - val_accuracy: 1.0000 - val_loss: 9.5682e-08
# Epoch 73/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.1381e-08 - val_accuracy: 1.0000 - val_loss: 8.9723e-08
# Epoch 74/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.9233e-08 - val_accuracy: 1.0000 - val_loss: 8.4222e-08
# Epoch 75/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7247e-08 - val_accuracy: 1.0000 - val_loss: 7.9020e-08
# Epoch 76/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.5401e-08 - val_accuracy: 1.0000 - val_loss: 7.4225e-08
# Epoch 77/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.3694e-08 - val_accuracy: 1.0000 - val_loss: 6.9810e-08
# Epoch 78/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.2100e-08 - val_accuracy: 1.0000 - val_loss: 6.5605e-08
# Epoch 79/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.0618e-08 - val_accuracy: 1.0000 - val_loss: 6.1646e-08
# Epoch 80/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.9241e-08 - val_accuracy: 1.0000 - val_loss: 5.8423e-08
# Epoch 81/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.7934e-08 - val_accuracy: 1.0000 - val_loss: 5.4882e-08
# Epoch 82/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6760e-08 - val_accuracy: 1.0000 - val_loss: 5.1609e-08
# Epoch 83/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5663e-08 - val_accuracy: 1.0000 - val_loss: 4.8534e-08
# Epoch 84/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4637e-08 - val_accuracy: 1.0000 - val_loss: 4.5687e-08
# Epoch 85/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3680e-08 - val_accuracy: 1.0000 - val_loss: 4.3010e-08
# Epoch 86/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.2790e-08 - val_accuracy: 1.0000 - val_loss: 4.0742e-08
# Epoch 87/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1943e-08 - val_accuracy: 1.0000 - val_loss: 3.8346e-08
# Epoch 88/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1172e-08 - val_accuracy: 1.0000 - val_loss: 3.6065e-08
# Epoch 89/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.0461e-08 - val_accuracy: 1.0000 - val_loss: 3.4002e-08
# Epoch 90/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.7885e-09 - val_accuracy: 1.0000 - val_loss: 3.2281e-08
# Epoch 91/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.1487e-09 - val_accuracy: 1.0000 - val_loss: 3.0394e-08
# Epoch 92/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.5732e-09 - val_accuracy: 1.0000 - val_loss: 2.8631e-08
# Epoch 93/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.0344e-09 - val_accuracy: 1.0000 - val_loss: 2.7007e-08
# Epoch 94/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.5265e-09 - val_accuracy: 1.0000 - val_loss: 2.5646e-08
# Epoch 95/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.0478e-09 - val_accuracy: 1.0000 - val_loss: 2.4166e-08
# Epoch 96/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.6128e-09 - val_accuracy: 1.0000 - val_loss: 2.2785e-08
# Epoch 97/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.2051e-09 - val_accuracy: 1.0000 - val_loss: 2.1508e-08
# Epoch 98/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.8200e-09 - val_accuracy: 1.0000 - val_loss: 2.0299e-08
# Epoch 99/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.4635e-09 - val_accuracy: 1.0000 - val_loss: 1.9318e-08
# Epoch 100/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.1179e-09 - val_accuracy: 1.0000 - val_loss: 1.8206e-08
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# [[647   0]
#  [  0 530]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       647
#            1       1.00      1.00      1.00       530
#
#     accuracy                           1.00      1177
#    macro avg       1.00      1.00      1.00      1177
# weighted avg       1.00      1.00      1.00      1177
#
# 1.0
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [[833   0]
#  [  0 638]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       833
#            1       1.00      1.00      1.00       638
#
#     accuracy                           1.00      1471
#    macro avg       1.00      1.00      1.00      1471
# weighted avg       1.00      1.00      1.00      1471
#
# 1.0

# %% [markdown]
# #### 2) 모델2

# %% [markdown]
# ### (2) 단계2

# %% [markdown]
# #### 1) 단계2-1 : 정적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 정적 행동(Laying, Sitting, Standing)인 데이터 추출
#     * Laying, Sitting, Standing 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
traindata_static=traindata[traindata['Activity'].isin(['LAYING','SITTING','STANDING'])]
traindata_static=traindata_static.drop(columns='is_dynamic')
traindata_static.head()
testdata_statict=testdata[testdata['Activity'].isin(['LAYING','SITTING','STANDING'])]
testdata_statict=testdata_statict.drop(columns='is_dynamic')
testdata_statict.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.284379          -0.021981          -0.116683         -0.992490
# 1           0.277440          -0.028086          -0.118412         -0.996620
# 3           0.276053          -0.016487          -0.108381         -0.995379
# 4           0.271998           0.016904          -0.078856         -0.973468
# 6           0.447718           0.207096          -0.117430         -0.843029
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.979640         -0.963321         -0.992563         -0.977304
# 1         -0.927676         -0.972294         -0.997346         -0.931405
# 3         -0.983978         -0.975854         -0.995877         -0.985280
# 4         -0.702462         -0.869450         -0.979810         -0.711601
# 6         -0.101380         -0.553765         -0.849087         -0.049920
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 0         -0.958142         -0.938850  ...                        -0.509523
# 1         -0.971788         -0.939837  ...                        -0.210792
# 3         -0.974907         -0.941425  ...                        -0.566291
# 4         -0.856807         -0.920760  ...                         0.447577
# 6         -0.552505         -0.710284  ...                        -0.298895
#
#    fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                        -0.850065                    -0.018043
# 1                        -0.613367                    -0.022456
# 3                        -0.841455                     0.289548
# 4                         0.214219                     0.010111
# 6                        -0.595825                    -0.052553
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.092304                          0.074220
# 1                             -0.155414                          0.247498
# 3                              0.079801                         -0.020033
# 4                              0.114179                         -0.830776
# 6                              0.173963                         -0.214500
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.714534             -0.671943
# 1                             -0.112257             -0.826816
# 3                              0.291898             -0.639435
# 4                             -0.325098             -0.840817
# 6                             -0.259947             -0.794966
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  Activity
# 0             -0.018351             -0.185733   SITTING
# 1              0.184489             -0.068699  STANDING
# 3             -0.111998             -0.123298   SITTING
# 4              0.116237             -0.096615  STANDING
# 6              0.233738             -0.024725  STANDING
#
# [5 rows x 562 columns]

# %%
from sklearn.preprocessing import StandardScaler
static_scaler=StandardScaler()
x_scaled_static = pd.DataFrame(static_scaler.fit_transform(traindata_static.drop(columns='Activity')),columns=traindata_static.drop(columns='Activity').columns)
x_test_scaled_static = pd.DataFrame(static_scaler.transform(testdata_statict.drop(columns='Activity')),columns=traindata_static.drop(columns='Activity').columns)

# 스케일러 저장
joblib.dump(static_scaler, path + 'static_scaler.pkl')

y_static=traindata_static['Activity']
y_test_static=testdata_statict['Activity']


y_scaled_static=pd.get_dummies(y_static)
y_test_scaled_static=pd.get_dummies(y_test_static)

print(x_scaled_static.head())
print(x_test_scaled_static.head())
print(y_static.shape)
print(y_test_static.shape)


y_test_scaled_static
# LAYINH: 0
# SITTING: 1
# STANDING: 2
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.235591           0.143563           0.057594         -0.266169
# 1          -0.142688          -0.016664           0.137155         -0.277956
# 2           0.072671           0.028157          -0.024359         -0.448243
# 3          -0.038452           0.314378          -0.281065         -0.330416
# 4           0.166255           0.819950           1.533433         -0.082042
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.210148         -0.225391         -0.234368         -0.196952
# 1         -0.475631         -0.402423         -0.260916         -0.449173
# 2         -0.362664         -0.460564         -0.433769         -0.354951
# 3          0.205199         -0.269878         -0.362759         -0.040053
# 4          0.827163          1.411674         -0.115707          0.983727
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0         -0.210194         -0.229748  ...                        -0.594136
# 1         -0.390286         -0.402333  ...                        -1.310371
# 2         -0.451599         -0.521642  ...                         0.811534
# 3         -0.298794         -0.131933  ...                        -1.451380
# 4          1.612454          0.128107  ...                        -1.135288
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                        -0.388852                        -0.508820
# 1                         0.387867                        -0.082793
# 2                        -0.536634                        -0.552450
# 3                         0.323585                        -0.122498
# 4                         0.962697                         0.931659
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.306532                             -0.183129
# 1                    -0.421312                              1.265874
# 2                    -0.066014                             -1.793306
# 3                    -0.204989                              0.220585
# 4                     0.051813                             -0.066744
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.732534                              0.174136
# 1                         -1.932076                              1.783803
# 2                         -2.247147                              0.056043
# 3                          1.808932                              1.687713
# 4                         -0.734360                              1.304219
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0             -0.485369              1.243243              1.064759
# 1              1.051424             -2.056302              0.066211
# 2             -0.862848              0.856874              0.433569
# 3             -0.836275              0.363096              0.972164
# 4             -0.779228              0.978003              0.457389
#
# [5 rows x 561 columns]
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.166938          -0.134019          -0.146264         -0.339210
# 1           0.051563          -0.266576          -0.172718         -0.425308
# 2           0.028512          -0.014737          -0.019206         -0.399445
# 3          -0.038917           0.710255           0.432633          0.057304
# 4           2.882729           4.839819          -0.157694          2.776438
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.350594         -0.189116         -0.313894         -0.315568
# 1          0.082698         -0.268492         -0.420661          0.054601
# 2         -0.386759         -0.299980         -0.387874         -0.379896
# 3          1.960604          0.641253         -0.029255          1.827305
# 4          6.972595          3.433762          2.888380          7.163722
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0         -0.148480         -0.436737  ...                         0.366322
# 1         -0.260656         -0.459195  ...                        -1.042024
# 2         -0.286292         -0.495289  ...                         0.640808
# 3          0.684516         -0.025379  ...                        -2.472670
# 4          3.185953          4.760871  ...                        -1.449930
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                        -0.456560                        -0.624227
# 1                         0.471869                         0.194401
# 2                        -0.632992                        -0.594450
# 3                         2.518019                         3.056647
# 4                         0.198050                         0.255073
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.168999                              0.274073
# 1                    -0.193822                             -0.555515
# 2                     1.561190                              0.232204
# 3                    -0.010633                              0.347333
# 4                    -0.363116                              0.547542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.152236                             -1.639618
# 1                          0.582589                             -0.252156
# 2                         -0.081849                              0.678893
# 3                         -2.095402                             -0.742477
# 4                         -0.564826                             -0.592389
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0             -0.600382              0.194903             -0.054303
# 1             -0.851891              0.803070              0.318937
# 2             -0.547591             -0.085876              0.144811
# 3             -0.874628              0.598432              0.229907
# 4             -0.800167              0.950733              0.459176
#
# [5 rows x 561 columns]
# (3234,)
# (833,)
#       LAYING  SITTING  STANDING
# 0      False     True     False
# 1      False    False      True
# 3      False     True     False
# 4      False    False      True
# 6      False    False      True
# ...      ...      ...       ...
# 1464   False     True     False
# 1465   False     True     False
# 1466   False     True     False
# 1467   False    False      True
# 1469    True    False     False
#
# [833 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split as tts
x_train_static,x_val_static,y_train_static,y_val_static=tts(x_scaled_static,y_scaled_static,test_size=0.2,stratify=y_scaled_static,random_state=42)

# %%
data1=x_train_static.copy()
df_train_dict={}
for f in featuresdata['sensor'].unique():
  columns_=[]
  for col in data1.columns:
    if '-' in col and f == col.split('-')[0]:
      columns_.append(col)
    elif f == 'angle' and f in col:
      columns_.append(col)
  p_data=data1[columns_]
  data1.drop(columns_,axis=1,inplace=True)
  df_train_dict[f] = p_data
print(df_train_dict.keys())


data1=x_val_static.copy()
df_val_dict={}
for f in featuresdata['sensor'].unique():
  columns_=[]
  for col in data1.columns:
    if '-' in col and f == col.split('-')[0]:
      columns_.append(col)
    elif f == 'angle' and f in col:
      columns_.append(col)
  p_data=data1[columns_]
  data1.drop(columns_,axis=1,inplace=True)
  df_val_dict[f] = p_data
print(df_val_dict.keys())


data1=x_test_scaled_static.copy()
df_test_dict={}
for f in featuresdata['sensor'].unique():
  columns_=[]
  for col in data1.columns:
    if '-' in col and f == col.split('-')[0]:
      columns_.append(col)
    elif f == 'angle' and f in col:
      columns_.append(col)
  p_data=data1[columns_]
  data1.drop(columns_,axis=1,inplace=True)
  df_test_dict[f] = p_data
print(len(df_test_dict.keys()))


df_train=[]
for k,v in df_train_dict.items():
  df_train.append(v.values)
df_val=[]
for k,v in df_val_dict.items():
  df_val.append(v.values)
df_test=[]
for k,v in df_test_dict.items():
  df_test.append(v.values)
# Out:
# dict_keys(['tBodyAcc', 'tGravityAcc', 'tBodyAccJerk', 'tBodyGyro', 'tBodyGyroJerk', 'tBodyAccMag', 'tGravityAccMag', 'tBodyAccJerkMag', 'tBodyGyroMag', 'tBodyGyroJerkMag', 'fBodyAcc', 'fBodyAccJerk', 'fBodyGyro', 'fBodyAccMag', 'fBodyBodyAccJerkMag', 'fBodyBodyGyroMag', 'fBodyBodyGyroJerkMag', 'angle'])
# dict_keys(['tBodyAcc', 'tGravityAcc', 'tBodyAccJerk', 'tBodyGyro', 'tBodyGyroJerk', 'tBodyAccMag', 'tGravityAccMag', 'tBodyAccJerkMag', 'tBodyGyroMag', 'tBodyGyroJerkMag', 'fBodyAcc', 'fBodyAccJerk', 'fBodyGyro', 'fBodyAccMag', 'fBodyBodyAccJerkMag', 'fBodyBodyGyroMag', 'fBodyBodyGyroJerkMag', 'angle'])
# 18

# %%
def Model_create(seed,df_dict):
  np.random.seed(seed)
  tf.random.set_seed(seed)
  random.seed(seed)

  input_1 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[0]].shape[1],))
  input_2 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[1]].shape[1],))
  input_3 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[2]].shape[1],))
  input_4 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[3]].shape[1],))
  input_5 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[4]].shape[1],))
  input_6 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[5]].shape[1],))
  input_7 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[6]].shape[1],))
  input_8 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[7]].shape[1],))
  input_9 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[8]].shape[1],))
  input_10 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[9]].shape[1],))
  input_11 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[10]].shape[1],))
  input_12 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[11]].shape[1],))
  input_13 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[12]].shape[1],))
  input_14 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[13]].shape[1],))
  input_15 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[14]].shape[1],))
  input_16 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[15]].shape[1],))
  input_17 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[16]].shape[1],))
  input_18 = tf.keras.layers.Input(shape=(df_dict[featuresdata['sensor'].unique()[17]].shape[1],))

  x1_1 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_1)
  x1_2 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_2)
  x1_3 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_3)
  x1_4 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_4)
  x1_5 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_5)
  x1_6 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_6)
  x1_7 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_7)
  x1_8 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_8)
  x1_9 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_9)
  x1_10 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_10)
  x1_11 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_11)
  x1_12 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_12)
  x1_13 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_13)
  x1_14 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_14)
  x1_15 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_15)
  x1_16 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_16)
  x1_17 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_17)
  x1_18 = tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal')(input_18)

  x2_1 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_1)
  x2_2 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_2)
  x2_3 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_3)
  x2_4 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_4)
  x2_5 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_5)
  x2_6 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_6)
  x2_7 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_7)
  x2_8 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_8)
  x2_9 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_9)
  x2_10 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_10)
  x2_11 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_11)
  x2_12 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_12)
  x2_13 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_13)
  x2_14 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_14)
  x2_15 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_15)
  x2_16 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_16)
  x2_17 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_17)
  x2_18 = tf.keras.layers.Dense(3, activation='relu', kernel_initializer='he_normal')(x1_18)

  concatenated = tf.keras.layers.Concatenate()([x2_1, x2_2, x2_3, x2_4, x2_5, x2_6, x2_7, x2_8, x2_9, x2_10,x2_11, x2_12, x2_13, x2_14, x2_15, x2_16, x2_17, x2_18])


  x3_1 = tf.keras.layers.Dense(16, activation='relu', kernel_initializer='he_normal')(concatenated)
  x3_2 = tf.keras.layers.Dense(3, activation='softmax')(x3_1)

  model = tf.keras.Model(inputs=[input_1, input_2, input_3, input_4, input_5, input_6, input_7, input_8, input_9,
                                input_10, input_11, input_12, input_13, input_14, input_15, input_16, input_17, input_18],
                        outputs=[x3_2])
  model.summary()
  return model

# %%
seed=42
model = Model_create(seed,df_train_dict)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_2             │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_3             │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_4             │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_5             │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_6             │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_7             │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_8             │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_9             │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_10            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_11            │ (None, 79)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_12            │ (None, 79)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_13            │ (None, 79)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_14            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_15            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_16            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_17            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_18            │ (None, 7)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 32)             │          1,312 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 32)             │          1,312 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 32)             │          1,312 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 32)             │          1,312 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 32)             │          1,312 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 32)             │            448 │ input_layer_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 32)             │            448 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 32)             │            448 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 32)             │            448 │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 32)             │            448 │ input_layer_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 32)             │          2,560 │ input_layer_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 32)             │          2,560 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 32)             │          2,560 │ input_layer_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 32)             │            448 │ input_layer_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 32)             │            448 │ input_layer_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 32)             │            448 │ input_layer_16[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 32)             │            448 │ input_layer_17[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 32)             │            256 │ input_layer_18[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 3)              │             99 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 3)              │             99 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 3)              │             99 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_24 (Dense)          │ (None, 3)              │             99 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_25 (Dense)          │ (None, 3)              │             99 │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_26 (Dense)          │ (None, 3)              │             99 │ dense_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_27 (Dense)          │ (None, 3)              │             99 │ dense_9[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_28 (Dense)          │ (None, 3)              │             99 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_29 (Dense)          │ (None, 3)              │             99 │ dense_11[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_30 (Dense)          │ (None, 3)              │             99 │ dense_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_31 (Dense)          │ (None, 3)              │             99 │ dense_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_32 (Dense)          │ (None, 3)              │             99 │ dense_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_33 (Dense)          │ (None, 3)              │             99 │ dense_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_34 (Dense)          │ (None, 3)              │             99 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_35 (Dense)          │ (None, 3)              │             99 │ dense_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_36 (Dense)          │ (None, 3)              │             99 │ dense_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_37 (Dense)          │ (None, 3)              │             99 │ dense_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_38 (Dense)          │ (None, 3)              │             99 │ dense_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 54)             │              0 │ dense_21[0][0],        │
# │                           │                        │                │ dense_22[0][0],        │
# │                           │                        │                │ dense_23[0][0],        │
# │                           │                        │                │ dense_24[0][0],        │
# │                           │                        │                │ dense_25[0][0],        │
# │                           │                        │                │ dense_26[0][0],        │
# │                           │                        │                │ dense_27[0][0],        │
# │                           │                        │                │ dense_28[0][0],        │
# │                           │                        │                │ dense_29[0][0],        │
# │                           │                        │                │ dense_30[0][0],        │
# │                           │                        │                │ dense_31[0][0],        │
# │                           │                        │                │ dense_32[0][0],        │
# │                           │                        │                │ dense_33[0][0],        │
# │                           │                        │                │ dense_34[0][0],        │
# │                           │                        │                │ dense_35[0][0],        │
# │                           │                        │                │ dense_36[0][0],        │
# │                           │                        │                │ dense_37[0][0],        │
# │                           │                        │                │ dense_38[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_39 (Dense)          │ (None, 16)             │            880 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_40 (Dense)          │ (None, 3)              │             51 │ dense_39[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,241 (82.97 KB)
#  Trainable params: 21,241 (82.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizers=tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizers,loss='categorical_crossentropy',metrics=['accuracy'])

er=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=50,restore_best_weights=True,verbose=1)
rd=tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',patience=5,verbose=1,factor=0.5,min_lr=0.000001)
cl=[er,rd]


history= model.fit(df_train,y_train_static,validation_split=0.2,batch_size=32,epochs=1000,callbacks=cl)
# Out:
# Epoch 1/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 18s 87ms/step - accuracy: 0.6793 - loss: 0.6565 - val_accuracy: 0.9247 - val_loss: 0.2155 - learning_rate: 0.0100
# Epoch 2/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9207 - loss: 0.1844 - val_accuracy: 0.9402 - val_loss: 0.1339 - learning_rate: 0.0100
# Epoch 3/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9651 - loss: 0.0851 - val_accuracy: 0.9421 - val_loss: 0.1698 - learning_rate: 0.0100
# Epoch 4/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9728 - loss: 0.0532 - val_accuracy: 0.9498 - val_loss: 0.1347 - learning_rate: 0.0100
# Epoch 5/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9890 - loss: 0.0308 - val_accuracy: 0.9266 - val_loss: 0.2599 - learning_rate: 0.0100
# Epoch 6/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9829 - loss: 0.0428 - val_accuracy: 0.9421 - val_loss: 0.1525 - learning_rate: 0.0100
# Epoch 7/1000
# 60/65 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9875 - loss: 0.0348
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9873 - loss: 0.0352 - val_accuracy: 0.9479 - val_loss: 0.1472 - learning_rate: 0.0100
# Epoch 8/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9889 - loss: 0.0311 - val_accuracy: 0.9691 - val_loss: 0.0848 - learning_rate: 0.0050
# Epoch 9/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9973 - loss: 0.0087 - val_accuracy: 0.9749 - val_loss: 0.0864 - learning_rate: 0.0050
# Epoch 10/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9998 - loss: 0.0033 - val_accuracy: 0.9788 - val_loss: 0.0907 - learning_rate: 0.0050
# Epoch 11/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9749 - val_loss: 0.0998 - learning_rate: 0.0050
# Epoch 12/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2457e-04 - val_accuracy: 0.9710 - val_loss: 0.1070 - learning_rate: 0.0050
# Epoch 13/1000
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.4726e-04
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4823e-04 - val_accuracy: 0.9710 - val_loss: 0.1122 - learning_rate: 0.0050
# Epoch 14/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.6960e-04 - val_accuracy: 0.9710 - val_loss: 0.1144 - learning_rate: 0.0025
# Epoch 15/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.4100e-04 - val_accuracy: 0.9710 - val_loss: 0.1163 - learning_rate: 0.0025
# Epoch 16/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.1707e-04 - val_accuracy: 0.9710 - val_loss: 0.1180 - learning_rate: 0.0025
# Epoch 17/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.9662e-04 - val_accuracy: 0.9710 - val_loss: 0.1197 - learning_rate: 0.0025
# Epoch 18/1000
# 55/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.7527e-04
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.7897e-04 - val_accuracy: 0.9710 - val_loss: 0.1214 - learning_rate: 0.0025
# Epoch 19/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.6405e-04 - val_accuracy: 0.9710 - val_loss: 0.1222 - learning_rate: 0.0012
# Epoch 20/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.5700e-04 - val_accuracy: 0.9710 - val_loss: 0.1231 - learning_rate: 0.0012
# Epoch 21/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.5025e-04 - val_accuracy: 0.9710 - val_loss: 0.1239 - learning_rate: 0.0012
# Epoch 22/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.4373e-04 - val_accuracy: 0.9710 - val_loss: 0.1246 - learning_rate: 0.0012
# Epoch 23/1000
# 56/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.3516e-04
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3770e-04 - val_accuracy: 0.9710 - val_loss: 0.1255 - learning_rate: 0.0012
# Epoch 24/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.3192e-04 - val_accuracy: 0.9710 - val_loss: 0.1259 - learning_rate: 6.2500e-04
# Epoch 25/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2894e-04 - val_accuracy: 0.9710 - val_loss: 0.1263 - learning_rate: 6.2500e-04
# Epoch 26/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2609e-04 - val_accuracy: 0.9691 - val_loss: 0.1268 - learning_rate: 6.2500e-04
# Epoch 27/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.2320e-04 - val_accuracy: 0.9691 - val_loss: 0.1272 - learning_rate: 6.2500e-04
# Epoch 28/1000
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.1958e-04
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.2031e-04 - val_accuracy: 0.9691 - val_loss: 0.1276 - learning_rate: 6.2500e-04
# Epoch 29/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.1758e-04 - val_accuracy: 0.9691 - val_loss: 0.1279 - learning_rate: 3.1250e-04
# Epoch 30/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.1619e-04 - val_accuracy: 0.9691 - val_loss: 0.1281 - learning_rate: 3.1250e-04
# Epoch 31/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.1470e-04 - val_accuracy: 0.9691 - val_loss: 0.1283 - learning_rate: 3.1250e-04
# Epoch 32/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.1327e-04 - val_accuracy: 0.9691 - val_loss: 0.1286 - learning_rate: 3.1250e-04
# Epoch 33/1000
# 59/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.1036e-04
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.1176e-04 - val_accuracy: 0.9691 - val_loss: 0.1289 - learning_rate: 3.1250e-04
# Epoch 34/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.1031e-04 - val_accuracy: 0.9691 - val_loss: 0.1290 - learning_rate: 1.5625e-04
# Epoch 35/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0954e-04 - val_accuracy: 0.9691 - val_loss: 0.1291 - learning_rate: 1.5625e-04
# Epoch 36/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0874e-04 - val_accuracy: 0.9691 - val_loss: 0.1293 - learning_rate: 1.5625e-04
# Epoch 37/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0796e-04 - val_accuracy: 0.9691 - val_loss: 0.1294 - learning_rate: 1.5625e-04
# Epoch 38/1000
# 63/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0647e-04
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0712e-04 - val_accuracy: 0.9691 - val_loss: 0.1296 - learning_rate: 1.5625e-04
# Epoch 39/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0631e-04 - val_accuracy: 0.9691 - val_loss: 0.1296 - learning_rate: 7.8125e-05
# Epoch 40/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0587e-04 - val_accuracy: 0.9691 - val_loss: 0.1297 - learning_rate: 7.8125e-05
# Epoch 41/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0541e-04 - val_accuracy: 0.9691 - val_loss: 0.1298 - learning_rate: 7.8125e-05
# Epoch 42/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0496e-04 - val_accuracy: 0.9691 - val_loss: 0.1299 - learning_rate: 7.8125e-05
# Epoch 43/1000
# 57/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0278e-04
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0449e-04 - val_accuracy: 0.9691 - val_loss: 0.1300 - learning_rate: 7.8125e-05
# Epoch 44/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0402e-04 - val_accuracy: 0.9691 - val_loss: 0.1300 - learning_rate: 3.9062e-05
# Epoch 45/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0377e-04 - val_accuracy: 0.9691 - val_loss: 0.1301 - learning_rate: 3.9062e-05
# Epoch 46/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0352e-04 - val_accuracy: 0.9691 - val_loss: 0.1301 - learning_rate: 3.9062e-05
# Epoch 47/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0325e-04 - val_accuracy: 0.9691 - val_loss: 0.1302 - learning_rate: 3.9062e-05
# Epoch 48/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0278e-04
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0298e-04 - val_accuracy: 0.9691 - val_loss: 0.1302 - learning_rate: 3.9062e-05
# Epoch 49/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0272e-04 - val_accuracy: 0.9691 - val_loss: 0.1303 - learning_rate: 1.9531e-05
# Epoch 50/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0257e-04 - val_accuracy: 0.9691 - val_loss: 0.1303 - learning_rate: 1.9531e-05
# Epoch 51/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.0242e-04 - val_accuracy: 0.9691 - val_loss: 0.1303 - learning_rate: 1.9531e-05
# Epoch 52/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.0227e-04 - val_accuracy: 0.9691 - val_loss: 0.1303 - learning_rate: 1.9531e-05
# Epoch 53/1000
# 58/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0065e-04
# Epoch 53: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.0211e-04 - val_accuracy: 0.9691 - val_loss: 0.1304 - learning_rate: 1.9531e-05
# Epoch 54/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 1.0195e-04 - val_accuracy: 0.9691 - val_loss: 0.1304 - learning_rate: 9.7656e-06
# Epoch 55/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.0187e-04 - val_accuracy: 0.9691 - val_loss: 0.1304 - learning_rate: 9.7656e-06
# Epoch 56/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.0178e-04 - val_accuracy: 0.9691 - val_loss: 0.1304 - learning_rate: 9.7656e-06
# Epoch 57/1000
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0169e-04 - val_accuracy: 0.9691 - val_loss: 0.1304 - learning_rate: 9.7656e-06
# Epoch 58/1000
# 55/65 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.9484e-05
# Epoch 58: ReduceLROnPlateau reducing learning rate to 4.882812390860636e-06.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0160e-04 - val_accuracy: 0.9691 - val_loss: 0.1305 - learning_rate: 9.7656e-06
# Epoch 58: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
with open(path+f'model_2_1_{seed}_history.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
model.save(path+f'model_2_1_{seed}.keras')

# %%
dl_history_plot(history.history)

pred=model.predict(df_val)
predict=np.argmax(pred,axis=1)
y_val_labels = np.argmax(y_val_static, axis=1)
print(confusion_matrix(y_val_labels,predict))
print(classification_report(y_val_labels,predict))
print(accuracy_score(y_val_labels,predict))


pred=model.predict(df_test)
predict=np.argmax(pred,axis=1)
y_val_labels = np.argmax(y_test_scaled_static, axis=1)
print(confusion_matrix(y_val_labels,predict))
print(classification_report(y_val_labels,predict))
print(accuracy_score(y_val_labels,predict))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# [[223   0   0]
#  [  0 196  10]
#  [  0   6 212]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       223
#            1       0.97      0.95      0.96       206
#            2       0.95      0.97      0.96       218
#
#     accuracy                           0.98       647
#    macro avg       0.98      0.97      0.97       647
# weighted avg       0.98      0.98      0.98       647
#
# 0.9752704791344667
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# [[292   0   0]
#  [  0 241  13]
#  [  0  14 273]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       0.95      0.95      0.95       254
#            2       0.95      0.95      0.95       287
#
#     accuracy                           0.97       833
#    macro avg       0.97      0.97      0.97       833
# weighted avg       0.97      0.97      0.97       833
#
# 0.9675870348139256

# %% [markdown]
# #### 2) 단계2-2 : 동적 동작 세부 분류

# %% [markdown]
# * 세부 요구사항
#     * 동동적 행동(Walking, Walking Upstairs, Walking Downstairs)인 데이터 추출
#     * Walking, Walking Upstairs, Walking Downstairs 를 분류하는 모델을 생성
#     * 몇가지 모델을 만들고 가장 성능이 좋은 모델을 선정하시오.

# %%
traindata_dynamic=traindata[traindata['Activity'].isin(['WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS'])]
traindata_dynamic=traindata_dynamic.drop(columns='is_dynamic')
traindata_dynamic.head()
testdata_dynamic=testdata[testdata['Activity'].isin(['WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS'])]
testdata_dynamic=testdata_dynamic.drop(columns='is_dynamic')
testdata_dynamic.head()
# Out:
#     tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 2            0.305833          -0.041023          -0.087303          0.006880
# 5            0.336801           0.010528          -0.057819         -0.435988
# 9            0.087902          -0.118993          -0.052787         -0.217817
# 16           0.267601          -0.032814          -0.113073         -0.290751
# 17           0.187920          -0.022493          -0.114320         -0.285203
#
#     tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 2           0.182800         -0.237984          0.005642          0.028616
# 5          -0.126317          0.037931         -0.446406         -0.244650
# 9          -0.148752          0.079020         -0.294967         -0.165066
# 16          0.028228         -0.011504         -0.341515          0.043469
# 17         -0.001438          0.163397         -0.339592         -0.134192
#
#     tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-skewness()  \
# 2          -0.236474          0.016311  ...                         0.579587
# 5          -0.034606         -0.288437  ...                         0.115015
# 9           0.137718          0.070103  ...                        -0.535753
# 16          0.048429         -0.226421  ...                        -0.475586
# 17          0.172202          0.093298  ...                        -0.381085
#
#     fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 2                          0.394388                    -0.362616
# 5                         -0.351891                    -0.174328
# 9                         -0.842876                     0.313940
# 16                        -0.795217                    -0.082706
# 17                        -0.806618                     0.765867
#
#     angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 2                               0.171069                          0.576349
# 5                               0.558749                          0.664988
# 9                               0.577018                         -0.968008
# 16                              0.206094                         -0.917195
# 17                             -0.099255                          0.815948
#
#     angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 2                              -0.688314             -0.743234
# 5                               0.544573             -0.775712
# 9                               0.525585             -0.872144
# 16                             -0.365769             -0.616598
# 17                              0.007978             -0.796053
#
#     angle(Y,gravityMean)  angle(Z,gravityMean)          Activity
# 2               0.272186              0.053101           WALKING
# 5               0.187548              0.149686           WALKING
# 9               0.186079              0.007999  WALKING_UPSTAIRS
# 16              0.353675              0.087181  WALKING_UPSTAIRS
# 17              0.199388              0.119815           WALKING
#
# [5 rows x 562 columns]

# %%
from sklearn.preprocessing import StandardScaler
dynamic_scaler=StandardScaler()
x_scaled_dynamic = pd.DataFrame(dynamic_scaler.fit_transform(traindata_dynamic.drop(columns='Activity')),columns=traindata_dynamic.drop(columns='Activity').columns)
x_test_scaled_dynamic = pd.DataFrame(dynamic_scaler.transform(testdata_dynamic.drop(columns='Activity')),columns=testdata_dynamic.drop(columns='Activity').columns)

# 스케일러 저장
joblib.dump(dynamic_scaler, path + 'dynamic_scaler.pkl')

y_dynamic=traindata_dynamic['Activity']
y_test_dynamic=testdata_dynamic['Activity']


y_scaled_dynamic=pd.get_dummies(y_dynamic)
y_test_scaled_dynamic=pd.get_dummies(y_test_dynamic)

print(x_scaled_dynamic.head())
print(x_test_scaled_dynamic.head())
print(y_dynamic.shape)
print(y_test_dynamic.shape)


y_test_scaled_dynamic

# WALKING: 0
# WALKING_DOWNSTAIRS: 1
# WALKING_UPSTAIRS: 2
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.190238          -0.524959          -0.789634         -0.326519
# 1           1.576887           1.863636           4.206142          0.912285
# 2           0.730484           0.953351           1.050471         -0.264751
# 3          -2.032496          -0.400311           2.212130         -0.018851
# 4           0.376298           0.788940           1.521092         -0.082521
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.090625         -0.592947         -0.289491          0.176821
# 1         -0.562670         -0.796362          0.747481         -0.422844
# 2          0.415627          1.066603         -0.274908          0.398516
# 3         -0.593133         -0.194500         -0.009027         -0.689072
# 4          0.836037          0.204979         -0.019798          0.597318
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0         -0.635554         -0.259621  ...                        -0.321056
# 1         -0.629078          1.584014  ...                        -0.712551
# 2          1.249280         -0.347831  ...                         0.063461
# 3         -0.212544          0.080968  ...                        -1.400565
# 4          0.318345         -0.288778  ...                         0.748173
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                         0.749569                         0.486171
# 1                         0.253769                         0.011899
# 2                        -1.171143                        -0.981545
# 3                        -0.433499                        -0.640012
# 4                         0.640825                         0.729410
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.555909                              1.085504
# 1                    -0.104193                             -1.433893
# 2                    -0.074836                             -1.445682
# 3                     0.944941                              0.020617
# 4                    -0.094949                              0.471147
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.940170                             -0.115627
# 1                         -1.240540                             -1.670696
# 2                         -0.639710                              0.607683
# 3                         -1.196895                              0.102551
# 4                          0.090076                             -0.211958
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0              0.218507              0.739518              0.204966
# 1              0.143735              0.432996              0.408432
# 2              1.380258              0.280205              1.592801
# 3             -1.330471             -0.831827             -0.697898
# 4             -0.244787              0.457531             -0.301931
#
# [5 rows x 561 columns]
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.402009          -0.713182           0.514211          0.596569
# 1           0.810934           1.055115           1.123937         -1.116733
# 2          -2.475689          -3.387713           1.227983         -0.272706
# 3          -0.102820          -0.431604          -0.018685         -0.554863
# 4          -1.154987          -0.077570          -0.044476         -0.533400
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0          0.800542         -0.188693          0.810985          0.246362
# 1         -0.655367          0.925226         -0.970785         -1.075956
# 2         -0.761032          1.091113         -0.373879         -0.690854
# 3          0.072526          0.725649         -0.557350          0.318234
# 4         -0.067199          1.431757         -0.549774         -0.541454
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0         -0.167963         -0.233936  ...                         2.201486
# 1          0.679050         -1.209625  ...                         0.320621
# 2          1.402093         -0.061713  ...                        -1.438185
# 3          1.027451         -1.011072  ...                         2.292175
# 4          1.546786          0.012547  ...                         1.054828
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                         2.630651                         2.952516
# 1                         1.133222                         0.661368
# 2                        -0.964361                        -0.846005
# 3                        -0.770428                        -0.699687
# 4                        -0.465828                        -0.734689
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.786269                              0.322232
# 1                    -0.382757                              0.992103
# 2                     0.663630                              1.023670
# 3                    -0.186406                              0.382751
# 4                     1.632135                             -0.144859
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.723583                             -1.289931
# 1                          0.835831                              1.062775
# 2                         -1.232129                              1.026541
# 3                         -1.167781                             -0.674420
# 4                          1.027001                              0.038797
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0             -0.166457              0.532872             -0.244764
# 1             -0.430144             -0.635645              0.500470
# 2             -1.213079             -0.655929             -0.592761
# 3              0.861708              1.657913              0.018194
# 4             -0.595293             -0.472180              0.269987
#
# [5 rows x 561 columns]
# (2647,)
# (638,)
#       WALKING  WALKING_DOWNSTAIRS  WALKING_UPSTAIRS
# 2        True               False             False
# 5        True               False             False
# 9       False               False              True
# 16      False               False              True
# 17       True               False             False
# ...       ...                 ...               ...
# 1459    False               False              True
# 1462    False                True             False
# 1463    False                True             False
# 1468    False                True             False
# 1470    False                True             False
#
# [638 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split as tts
x_train_dynamic,x_val_dynamic,y_train_dynamic,y_val_dynamic=tts(x_scaled_dynamic,y_scaled_dynamic,test_size=0.2,stratify=y_scaled_dynamic,random_state=42)

# %%
data1=x_train_dynamic.copy()
df_train_dict={}
for f in featuresdata['sensor'].unique():
  columns_=[]
  for col in data1.columns:
    if '-' in col and f == col.split('-')[0]:
      columns_.append(col)
    elif f == 'angle' and f in col:
      columns_.append(col)
  p_data=data1[columns_]
  data1.drop(columns_,axis=1,inplace=True)
  df_train_dict[f] = p_data
print(df_train_dict.keys())


data1=x_val_dynamic.copy()
df_val_dict={}
for f in featuresdata['sensor'].unique():
  columns_=[]
  for col in data1.columns:
    if '-' in col and f == col.split('-')[0]:
      columns_.append(col)
    elif f == 'angle' and f in col:
      columns_.append(col)
  p_data=data1[columns_]
  data1.drop(columns_,axis=1,inplace=True)
  df_val_dict[f] = p_data
print(df_val_dict.keys())


data1=x_test_scaled_dynamic.copy()
df_test_dict={}
for f in featuresdata['sensor'].unique():
  columns_=[]
  for col in data1.columns:
    if '-' in col and f == col.split('-')[0]:
      columns_.append(col)
    elif f == 'angle' and f in col:
      columns_.append(col)
  p_data=data1[columns_]
  data1.drop(columns_,axis=1,inplace=True)
  df_test_dict[f] = p_data
print(len(df_test_dict.keys()))


df_train=[]
for k,v in df_train_dict.items():
  df_train.append(v.values)
df_val=[]
for k,v in df_val_dict.items():
  df_val.append(v.values)
df_test=[]
for k,v in df_test_dict.items():
  df_test.append(v.values)
# Out:
# dict_keys(['tBodyAcc', 'tGravityAcc', 'tBodyAccJerk', 'tBodyGyro', 'tBodyGyroJerk', 'tBodyAccMag', 'tGravityAccMag', 'tBodyAccJerkMag', 'tBodyGyroMag', 'tBodyGyroJerkMag', 'fBodyAcc', 'fBodyAccJerk', 'fBodyGyro', 'fBodyAccMag', 'fBodyBodyAccJerkMag', 'fBodyBodyGyroMag', 'fBodyBodyGyroJerkMag', 'angle'])
# dict_keys(['tBodyAcc', 'tGravityAcc', 'tBodyAccJerk', 'tBodyGyro', 'tBodyGyroJerk', 'tBodyAccMag', 'tGravityAccMag', 'tBodyAccJerkMag', 'tBodyGyroMag', 'tBodyGyroJerkMag', 'fBodyAcc', 'fBodyAccJerk', 'fBodyGyro', 'fBodyAccMag', 'fBodyBodyAccJerkMag', 'fBodyBodyGyroMag', 'fBodyBodyGyroJerkMag', 'angle'])
# 18

# %%
seed=42
model = Model_create(seed,df_train_dict)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_19            │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_20            │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_21            │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_22            │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_23            │ (None, 40)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_24            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_25            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_26            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_27            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_28            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_29            │ (None, 79)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_30            │ (None, 79)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_31            │ (None, 79)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_32            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_33            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_34            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_35            │ (None, 13)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_36            │ (None, 7)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_41 (Dense)          │ (None, 32)             │          1,312 │ input_layer_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_42 (Dense)          │ (None, 32)             │          1,312 │ input_layer_20[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_43 (Dense)          │ (None, 32)             │          1,312 │ input_layer_21[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_44 (Dense)          │ (None, 32)             │          1,312 │ input_layer_22[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_45 (Dense)          │ (None, 32)             │          1,312 │ input_layer_23[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_46 (Dense)          │ (None, 32)             │            448 │ input_layer_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_47 (Dense)          │ (None, 32)             │            448 │ input_layer_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_48 (Dense)          │ (None, 32)             │            448 │ input_layer_26[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_49 (Dense)          │ (None, 32)             │            448 │ input_layer_27[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_50 (Dense)          │ (None, 32)             │            448 │ input_layer_28[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_51 (Dense)          │ (None, 32)             │          2,560 │ input_layer_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_52 (Dense)          │ (None, 32)             │          2,560 │ input_layer_30[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_53 (Dense)          │ (None, 32)             │          2,560 │ input_layer_31[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_54 (Dense)          │ (None, 32)             │            448 │ input_layer_32[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_55 (Dense)          │ (None, 32)             │            448 │ input_layer_33[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_56 (Dense)          │ (None, 32)             │            448 │ input_layer_34[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_57 (Dense)          │ (None, 32)             │            448 │ input_layer_35[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_58 (Dense)          │ (None, 32)             │            256 │ input_layer_36[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_59 (Dense)          │ (None, 3)              │             99 │ dense_41[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_60 (Dense)          │ (None, 3)              │             99 │ dense_42[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_61 (Dense)          │ (None, 3)              │             99 │ dense_43[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_62 (Dense)          │ (None, 3)              │             99 │ dense_44[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_63 (Dense)          │ (None, 3)              │             99 │ dense_45[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_64 (Dense)          │ (None, 3)              │             99 │ dense_46[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_65 (Dense)          │ (None, 3)              │             99 │ dense_47[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_66 (Dense)          │ (None, 3)              │             99 │ dense_48[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_67 (Dense)          │ (None, 3)              │             99 │ dense_49[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_68 (Dense)          │ (None, 3)              │             99 │ dense_50[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_69 (Dense)          │ (None, 3)              │             99 │ dense_51[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_70 (Dense)          │ (None, 3)              │             99 │ dense_52[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_71 (Dense)          │ (None, 3)              │             99 │ dense_53[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_72 (Dense)          │ (None, 3)              │             99 │ dense_54[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_73 (Dense)          │ (None, 3)              │             99 │ dense_55[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_74 (Dense)          │ (None, 3)              │             99 │ dense_56[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_75 (Dense)          │ (None, 3)              │             99 │ dense_57[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_76 (Dense)          │ (None, 3)              │             99 │ dense_58[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 54)             │              0 │ dense_59[0][0],        │
# │ (Concatenate)             │                        │                │ dense_60[0][0],        │
# │                           │                        │                │ dense_61[0][0],        │
# │                           │                        │                │ dense_62[0][0],        │
# │                           │                        │                │ dense_63[0][0],        │
# │                           │                        │                │ dense_64[0][0],        │
# │                           │                        │                │ dense_65[0][0],        │
# │                           │                        │                │ dense_66[0][0],        │
# │                           │                        │                │ dense_67[0][0],        │
# │                           │                        │                │ dense_68[0][0],        │
# │                           │                        │                │ dense_69[0][0],        │
# │                           │                        │                │ dense_70[0][0],        │
# │                           │                        │                │ dense_71[0][0],        │
# │                           │                        │                │ dense_72[0][0],        │
# │                           │                        │                │ dense_73[0][0],        │
# │                           │                        │                │ dense_74[0][0],        │
# │                           │                        │                │ dense_75[0][0],        │
# │                           │                        │                │ dense_76[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_77 (Dense)          │ (None, 16)             │            880 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_78 (Dense)          │ (None, 3)              │             51 │ dense_77[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,241 (82.97 KB)
#  Trainable params: 21,241 (82.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizers=tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizers,loss='categorical_crossentropy',metrics=['accuracy'])

er=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=50,restore_best_weights=True,verbose=1)
rd=tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',patience=5,verbose=1,factor=0.5,min_lr=0.000001)
cl=[er,rd]


history= model.fit(df_train,y_train_dynamic,validation_split=0.2,batch_size=32,epochs=1000,callbacks=cl)
# Out:
# Epoch 1/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 124ms/step - accuracy: 0.8264 - loss: 0.4323 - val_accuracy: 0.9764 - val_loss: 0.0761 - learning_rate: 0.0100
# Epoch 2/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9876 - loss: 0.0434 - val_accuracy: 0.9811 - val_loss: 0.0602 - learning_rate: 0.0100
# Epoch 3/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9895 - loss: 0.0255 - val_accuracy: 0.9882 - val_loss: 0.0330 - learning_rate: 0.0100
# Epoch 4/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9975 - loss: 0.0062 - val_accuracy: 0.9858 - val_loss: 0.0358 - learning_rate: 0.0100
# Epoch 5/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.1091e-04 - val_accuracy: 0.9906 - val_loss: 0.0310 - learning_rate: 0.0100
# Epoch 6/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.5918e-04 - val_accuracy: 0.9882 - val_loss: 0.0329 - learning_rate: 0.0100
# Epoch 7/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.4173e-04 - val_accuracy: 0.9882 - val_loss: 0.0324 - learning_rate: 0.0100
# Epoch 8/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.1019e-04 - val_accuracy: 0.9882 - val_loss: 0.0322 - learning_rate: 0.0100
# Epoch 9/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 8.6836e-05 - val_accuracy: 0.9882 - val_loss: 0.0321 - learning_rate: 0.0100
# Epoch 10/1000
# 46/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.0677e-05
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 7.1158e-05 - val_accuracy: 0.9882 - val_loss: 0.0320 - learning_rate: 0.0100
# Epoch 11/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.0275e-05 - val_accuracy: 0.9906 - val_loss: 0.0319 - learning_rate: 0.0050
# Epoch 12/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 5.5616e-05 - val_accuracy: 0.9906 - val_loss: 0.0320 - learning_rate: 0.0050
# Epoch 13/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 5.1202e-05 - val_accuracy: 0.9906 - val_loss: 0.0320 - learning_rate: 0.0050
# Epoch 14/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.7296e-05 - val_accuracy: 0.9906 - val_loss: 0.0319 - learning_rate: 0.0050
# Epoch 15/1000
# 44/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.3257e-05
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 4.3835e-05 - val_accuracy: 0.9906 - val_loss: 0.0319 - learning_rate: 0.0050
# Epoch 16/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 4.0771e-05 - val_accuracy: 0.9906 - val_loss: 0.0319 - learning_rate: 0.0025
# Epoch 17/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 3.9274e-05 - val_accuracy: 0.9906 - val_loss: 0.0319 - learning_rate: 0.0025
# Epoch 18/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7817e-05 - val_accuracy: 0.9906 - val_loss: 0.0319 - learning_rate: 0.0025
# Epoch 19/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.6408e-05 - val_accuracy: 0.9906 - val_loss: 0.0318 - learning_rate: 0.0025
# Epoch 20/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.5023e-05
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 3.5063e-05 - val_accuracy: 0.9906 - val_loss: 0.0318 - learning_rate: 0.0025
# Epoch 21/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.3831e-05 - val_accuracy: 0.9906 - val_loss: 0.0318 - learning_rate: 0.0012
# Epoch 22/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.3188e-05 - val_accuracy: 0.9906 - val_loss: 0.0317 - learning_rate: 0.0012
# Epoch 23/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.2552e-05 - val_accuracy: 0.9906 - val_loss: 0.0317 - learning_rate: 0.0012
# Epoch 24/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.1914e-05 - val_accuracy: 0.9906 - val_loss: 0.0317 - learning_rate: 0.0012
# Epoch 25/1000
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.1204e-05
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 3.1280e-05 - val_accuracy: 0.9906 - val_loss: 0.0316 - learning_rate: 0.0012
# Epoch 26/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.0681e-05 - val_accuracy: 0.9906 - val_loss: 0.0316 - learning_rate: 6.2500e-04
# Epoch 27/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.0366e-05 - val_accuracy: 0.9906 - val_loss: 0.0316 - learning_rate: 6.2500e-04
# Epoch 28/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.0047e-05 - val_accuracy: 0.9906 - val_loss: 0.0316 - learning_rate: 6.2500e-04
# Epoch 29/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.9723e-05 - val_accuracy: 0.9906 - val_loss: 0.0316 - learning_rate: 6.2500e-04
# Epoch 30/1000
# 51/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.9285e-05
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.9396e-05 - val_accuracy: 0.9906 - val_loss: 0.0316 - learning_rate: 6.2500e-04
# Epoch 31/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9081e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.1250e-04
# Epoch 32/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.8912e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.1250e-04
# Epoch 33/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.8739e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.1250e-04
# Epoch 34/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.8562e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.1250e-04
# Epoch 35/1000
# 44/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.7954e-05
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.8382e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.1250e-04
# Epoch 36/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.8210e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 1.5625e-04
# Epoch 37/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.8116e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 1.5625e-04
# Epoch 38/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.8019e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 1.5625e-04
# Epoch 39/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.7920e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 1.5625e-04
# Epoch 40/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.7785e-05
# Epoch 40: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7819e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 1.5625e-04
# Epoch 41/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.7723e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 7.8125e-05
# Epoch 42/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.7671e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 7.8125e-05
# Epoch 43/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7617e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 7.8125e-05
# Epoch 44/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7561e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 7.8125e-05
# Epoch 45/1000
# 44/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.7087e-05
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7504e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 7.8125e-05
# Epoch 46/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.7449e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.9062e-05
# Epoch 47/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.7418e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.9062e-05
# Epoch 48/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.7388e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.9062e-05
# Epoch 49/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.7356e-05 - val_accuracy: 0.9906 - val_loss: 0.0315 - learning_rate: 3.9062e-05
# Epoch 50/1000
# 45/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.6962e-05
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.7322e-05 - val_accuracy: 0.9906 - val_loss: 0.0314 - learning_rate: 3.9062e-05
# Epoch 51/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.7291e-05 - val_accuracy: 0.9906 - val_loss: 0.0314 - learning_rate: 1.9531e-05
# Epoch 52/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.7273e-05 - val_accuracy: 0.9906 - val_loss: 0.0314 - learning_rate: 1.9531e-05
# Epoch 53/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.7257e-05 - val_accuracy: 0.9906 - val_loss: 0.0314 - learning_rate: 1.9531e-05
# Epoch 54/1000
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.7238e-05 - val_accuracy: 0.9906 - val_loss: 0.0314 - learning_rate: 1.9531e-05
# Epoch 55/1000
# 52/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.7151e-05
# Epoch 55: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.7219e-05 - val_accuracy: 0.9906 - val_loss: 0.0314 - learning_rate: 1.9531e-05
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
with open(path+f'model_2_2_{seed}_history.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)
model.save(path+f'model_2_2_{seed}.keras')

# %%
dl_history_plot(history.history)

pred=model.predict(df_val)
predict=np.argmax(pred,axis=1)
y_val_labels = np.argmax(y_val_dynamic, axis=1)
print(confusion_matrix(y_val_labels,predict))
print(classification_report(y_val_labels,predict))
print(accuracy_score(y_val_labels,predict))


pred=model.predict(df_test)
predict=np.argmax(pred,axis=1)
y_val_labels = np.argmax(y_test_scaled_dynamic, axis=1)
print(confusion_matrix(y_val_labels,predict))
print(classification_report(y_val_labels,predict))
print(accuracy_score(y_val_labels,predict))
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
# [[198   0   2]
#  [  0 158   0]
#  [  1   0 171]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       200
#            1       1.00      1.00      1.00       158
#            2       0.99      0.99      0.99       172
#
#     accuracy                           0.99       530
#    macro avg       0.99      0.99      0.99       530
# weighted avg       0.99      0.99      0.99       530
#
# 0.9943396226415094
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# [[224   0   4]
#  [  0 195   0]
#  [  0   0 215]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       228
#            1       1.00      1.00      1.00       195
#            2       0.98      1.00      0.99       215
#
#     accuracy                           0.99       638
#    macro avg       0.99      0.99      0.99       638
# weighted avg       0.99      0.99      0.99       638
#
# 0.9937304075235109

# %% [markdown]
# ### (3) 분류 모델 파이프라인 구성

# %% [markdown]
# * 세부 요구사항
#     * 두 단계 모델을 통합하고, 새로운 데이터(test)에 대해서 최종 예측결과와 성능평가가 나오도록 함수로 만들기
#     * 데이터 파이프라인 구축 : test데이터가 로딩되어 전처리 과정을 거치고, 예측 및 성능 평가 수행

# %% [markdown]
# * 예시
# ![](https://github.com/DA4BAM/image/blob/main/pipeline%20function.png?raw=true)

# %% [markdown]
# #### 1) 함수 만들기

# %%
def data_preprocessing(scaler,static_scaler,dynamic_scaler,testdata,featuresdata):
  data=testdata.copy()
  data['is_dynamic']=np.where(testdata['Activity'].isin(['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS']),1,0)

  x_1=scaler.transform(data.drop(columns=['Activity','is_dynamic']))
  y_1=data['is_dynamic']

  data.loc[data['is_dynamic']==0,data.columns[:-2]] =  static_scaler.transform(data.loc[data['is_dynamic']==0,data.columns[:-2]])
  data.loc[data['is_dynamic']==1,data.columns[:-2]] =  dynamic_scaler.transform(data.loc[data['is_dynamic']==1,data.columns[:-2]])


  data1=data.copy()
  test_dict={}
  for f in featuresdata['sensor'].unique():
    columns_=[]
    for col in data1.columns:
      if '-' in col and f == col.split('-')[0]:
        columns_.append(col)
      elif f == 'angle' and f in col:
        columns_.append(col)
    p_data=data1[columns_]
    data1.drop(columns_,axis=1,inplace=True)
    test_dict[f] = p_data

  x_2=[]
  for k,v in test_dict.items():
    x_2.append(v.values)
  y_2=pd.get_dummies(data['Activity'])

  return x_1,y_1,x_2,y_2

# %%
x_1,y_1,x_2,y_2 = data_preprocessing(scaler,static_scaler,dynamic_scaler,testdata,featuresdata)

# %%
model_1 = load_model(path + f'1_step_model.keras')
model_2_1 = load_model(path + f'model_2_1_{seed}.keras')
model_2_2 = load_model(path + f'model_2_2_{seed}.keras')

# %% [markdown]
# #### 2) test 셋으로 예측하고 평가하기

# %%
# 데이터 전처리 (model1/2 입력 및 정답)
x_1,y_1,x_2,y_2=data_preprocessing(scaler,static_scaler,dynamic_scaler,testdata,featuresdata)

# model 1 예측 및 결과 저장
result_1 = model_1.predict(x_1)
result_1=np.where(result_1>0.5,1,0) ## pred_y_1

indices_0 = np.where(result_1.squeeze() == 0)[0]
indices_1 = np.where(result_1.squeeze() == 1)[0]

x_2_0 = [arr[indices_0] for arr in x_2] if len(indices_0) > 0 else None
x_2_1 = [arr[indices_1] for arr in x_2] if len(indices_1) > 0 else None


if x_2_0:
    pred_0 = model_2_1.predict(x_2_0) # pred_y_2_0
    pred_0 = np.argmax(pred_0, axis=1)

if x_2_1:
    pred_1 = model_2_2.predict(x_2_1) # pred_y_2_1
    pred_1 = np.argmax(pred_1, axis=1) + 3

result_2 = np.empty(shape=(len(result_1),), dtype=int)

if len(indices_0) > 0:
    result_2[indices_0] = pred_0
if len(indices_1) > 0:
    result_2[indices_1] = pred_1

accuracy_1 = accuracy_score(np.argmax(y_2, axis=1), result_2)
classification_report_1 = classification_report(np.argmax(y_2, axis=1), result_2)
confusion_matrix_1 = confusion_matrix(np.argmax(y_2, axis=1), result_2)

print(f'Accuracy: {accuracy_1}')
print(f'classification_report: {classification_report_1}')
print(f'confusion_matrix: {confusion_matrix_1}')
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
# Accuracy: 0.9789259007477906
# classification_report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       0.95      0.95      0.95       254
#            2       0.95      0.95      0.95       287
#            3       1.00      0.98      0.99       228
#            4       1.00      1.00      1.00       195
#            5       0.98      1.00      0.99       215
#
#     accuracy                           0.98      1471
#    macro avg       0.98      0.98      0.98      1471
# weighted avg       0.98      0.98      0.98      1471
#
# confusion_matrix: [[292   0   0   0   0   0]
#  [  0 241  13   0   0   0]
#  [  0  14 273   0   0   0]
#  [  0   0   0 224   0   4]
#  [  0   0   0   0 195   0]
#  [  0   0   0   0   0 215]]

# %%
def p3_model(test_data, featuresdata) :

  # scaler, model load
  scaler = joblib.load(path + 'scaler.pkl')
  dynamic_scaler = joblib.load(path + 'dynamic_scaler.pkl')
  static_scaler = joblib.load(path + 'static_scaler.pkl')

  model_1 = load_model(path + f'1_step_model.keras')
  model_2_1 = load_model(path + f'model_2_1_42.keras')
  model_2_2 = load_model(path + f'model_2_2_42.keras')

  # 데이터 전처리 (model1/2 입력 및 정답)
  x_1,y_1,x_2,y_2=data_preprocessing(scaler,static_scaler,dynamic_scaler,testdata,featuresdata)

  # model 1 예측 및 결과 저장
  result_1 = model_1.predict(x_1)
  result_1=np.where(result_1>0.5,1,0) ## pred_y_1

  indices_0 = np.where(result_1.squeeze() == 0)[0]
  indices_1 = np.where(result_1.squeeze() == 1)[0]

  x_2_0 = [arr[indices_0] for arr in x_2] if len(indices_0) > 0 else None
  x_2_1 = [arr[indices_1] for arr in x_2] if len(indices_1) > 0 else None


  if x_2_0:
      pred_0 = model_2_1.predict(x_2_0) # pred_y_2_0
      pred_0 = np.argmax(pred_0, axis=1)

  if x_2_1:
      pred_1 = model_2_2.predict(x_2_1) # pred_y_2_1
      pred_1 = np.argmax(pred_1, axis=1) + 3

  result_2 = np.empty(shape=(len(result_1),), dtype=int)

  if len(indices_0) > 0:
      result_2[indices_0] = pred_0
  if len(indices_1) > 0:
      result_2[indices_1] = pred_1

  accuracy_1 = accuracy_score(np.argmax(y_2, axis=1), result_2)
  classification_report_1 = classification_report(np.argmax(y_2, axis=1), result_2)
  confusion_matrix_1 = confusion_matrix(np.argmax(y_2, axis=1), result_2)

  print('Accuracy:', accuracy_1)
  print('classification_report\n', classification_report_1)
  print('confusion_matrix\n', confusion_matrix_1)

# %%
p3_model(testdata,featuresdata)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# Accuracy: 0.9789259007477906
# classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       292
#            1       0.95      0.95      0.95       254
#            2       0.95      0.95      0.95       287
#            3       1.00      0.98      0.99       228
#            4       1.00      1.00      1.00       195
#            5       0.98      1.00      0.99       215
#
#     accuracy                           0.98      1471
#    macro avg       0.98      0.98      0.98      1471
# weighted avg       0.98      0.98      0.98      1471
#
# confusion_matrix
#  [[292   0   0   0   0   0]
#  [  0 241  13   0   0   0]
#  [  0  14 273   0   0   0]
#  [  0   0   0 224   0   4]
#  [  0   0   0   0 195   0]
#  [  0   0   0   0   0 215]]
