# %% [markdown]
# # **Make Pretrained-Model FaceNet !**

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (3) 미션3
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
! Get-ExecutionPolicy
# Out:
# /bin/bash: line 1: Get-ExecutionPolicy: command not found

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/kt aivle/미니프로젝트 4차'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install keras-nightly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 3.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 데이터셋은 두 개의 압축 파일이어야 합니다.
#             1. lfw-deepfunneled.zip : Labeled Faces in the Wild 데이터셋
#             2. 여러분의 얼굴 이미지 데이터셋
#                 - 여러분의 얼굴 이미지가 담긴 **압축 파일**을 **Google Drive에 업로드** 하기를 권장합니다.
#                     - 이미지 파일 하나하나 업로드 하면 시간이 오래 걸립니다.
#     - 데이터셋 압축 파일을 **Colab에 폴더를 생성한 후 해제**하세요.
#         - 데이터셋 폴더를 **본인 얼굴 폴더, LFW 폴더로 나누어** 생성하는 것을 권장합니다.
#         - 만일 두 압축 파일을 하나의 폴더에 모두 해제하면 전처리가 더 까다로워질 것입니다.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %% [markdown]
# #### 1) 본인 얼굴 이미지 데이터셋 불러오기

# %%
def preprocess_image(image_path):
    image = load_img(image_path, target_size=(160, 160))  # 크기 조정
    image = img_to_array(image) / 255.0  # 정규화
    return image

# %%
import os
import cv2

folder_path = '/content/drive/MyDrive/kt aivle/미니프로젝트 4차/image'

image_files = [f for f in os.listdir(folder_path) if f.endswith(('.png', '.jpg', '.jpeg'))]

images_myface = []

for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    image = cv2.imread(image_path)
    if image is not None:
        images_myface.append(image)
print(f"총 {len(images_myface)}개의 이미지가 불러와졌습니다.")
# Out:
# 총 2500개의 이미지가 불러와졌습니다.

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
my_face_images = []
for image_file in image_files:  # 이전에 불러온 이미지 리스트
    image_path = os.path.join(folder_path, image_file)
    processed_image = preprocess_image(image_path)
    my_face_images.append(processed_image)

my_face_images = np.array(my_face_images)

# %%
my_face_images
# Out:
# array([[[[0.5921569 , 0.6039216 , 0.62352943],
#          [0.6039216 , 0.6156863 , 0.63529414],
#          [0.5921569 , 0.6117647 , 0.627451  ],
#          ...,
#          [0.60784316, 0.6313726 , 0.6156863 ],
#          [0.6117647 , 0.63529414, 0.61960787],
#          [0.627451  , 0.64705884, 0.6313726 ]],
#
#         [[0.5921569 , 0.6117647 , 0.627451  ],
#          [0.5921569 , 0.6117647 , 0.627451  ],
#          [0.5921569 , 0.6117647 , 0.627451  ],
#          ...,
#          [0.61960787, 0.6392157 , 0.62352943],
#          [0.6156863 , 0.63529414, 0.61960787],
#          [0.61960787, 0.6392157 , 0.62352943]],
#
#         [[0.6       , 0.61960787, 0.63529414],
#          [0.5921569 , 0.6117647 , 0.627451  ],
#          [0.6       , 0.61960787, 0.6313726 ],
#          ...,
#          [0.6156863 , 0.63529414, 0.61960787],
#          [0.6156863 , 0.63529414, 0.61960787],
#          [0.61960787, 0.6392157 , 0.62352943]],
#
#         ...,
#
# ...

# %% [markdown]
# #### 2) 다른 얼굴 이미지 데이터셋 불러오기

# %%
import os
import cv2
import numpy as np

# 최상위 폴더 경로 설정
base_folder_path = '/content/drive/MyDrive/kt aivle/미니프로젝트 4차/Datasets/Keras/lfw-deepfunneled'

# 이미지를 저장할 리스트
images = []

# 최상위 폴더 내 모든 하위 폴더 탐색
for person_folder in os.listdir(base_folder_path):
    person_folder_path = os.path.join(base_folder_path, person_folder)

    # 하위 폴더가 실제 폴더인지 확인
    if os.path.isdir(person_folder_path):
        # 하위 폴더 내 이미지 파일들을 탐색
        for image_file in os.listdir(person_folder_path):
            # 이미지 파일의 전체 경로
            image_path = os.path.join(person_folder_path, image_file)
            # 이미지 파일인지 확인 후 불러오기
            if image_file.endswith(('.png', '.jpg', '.jpeg')):
                image = cv2.imread(image_path)
                if image is not None:
                    # 이미지 정규화
                    image = cv2.resize(image, (160, 160))  # 크기 조정
                    image = image.astype('float32') / 255.0  # 정규화
                    images.append(image)

print(f"총 {len(images)}개의 이미지가 불러와졌습니다.")
# Out:
# 총 0개의 이미지가 불러와졌습니다.

# %% [markdown]
# ### (2) 데이터셋 전처리
# * **세부 요구사항**
#     - 데이터셋을 전처리 합니다.
#         - Training set, Validation set, Test set으로 데이터셋을 나누어 주세요.
#             - 학습 과정에서 Training set, Validation set을 사용해야 합니다.
#             - 추론 과정에서 Test set을 사용해야 합니다.
#         - Keras의 **특정 함수**가 실제 존재하는 이미지 파일에 대한 전처리를 쉽게 도와줍니다.
#         - **특정 함수**에서 요구하는 폴더 구조가 있습니다. **특정 함수**를 사용한다면 이에 맞춰서 폴더를 생성해야 합니다.
#         - 각 데이터셋에 스케일링도 적용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - glob, random, shutil, numpy, keras

# %% [markdown]
# #### 1) 데이터셋 분할

# %%
# 내 얼굴 데이터 + 다른사람 얼굴 데이터 합쳐서 x 에 넣고 y에는 라벨링 이 들어간다.
x = np.concatenate((my_face_images, images), axis=0)
# 레이블 생성
y_my_face = np.ones(len(my_face_images))  # 내 얼굴 레이블: 1
y_other_faces = np.zeros(len(images))     # 다른 사람 얼굴 레이블: 0

# 레이블 통합
y = np.concatenate((y_my_face, y_other_faces), axis=0)

# 데이터 섞기
indices = np.arange(len(x))
np.random.shuffle(indices)

x = x[indices]
y = y[indices]

print(f"훈련 데이터 수: {len(x)}, 레이블 수: {len(y)}")
# Out:
# 훈련 데이터 수: 16233, 레이블 수: 16233

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size= 0.2 , random_state= 42)

# %% [markdown]
# #### 2) **특정 함수** 사용

# %% [markdown]
# #### 3) 스케일링

# %% [markdown]
# ## 4.미션2

# %% [markdown]
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (1) FaceNet 구조 생성

# %% [markdown]
# * **세부 요구사항**
#     - FaceNet의 구조를 생성합니다.
#         - FaceNet 구조 생성에 필요한 함수를 만듭니다.
#     - FaceNet의 구조에 **잘 학습된 가중치**를 부여합니다.
#         - FaceNet 원본 가중치 파일을 공유하였습니다.
#     - (선택사항) FaceNet 모델의 가중치 업데이트를 방지합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - numpy, functools, keras

# %% [markdown]
# #### 1) 모델 구조 생성

# %%
import numpy as np
from functools import partial


import keras
from keras.models import Model

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation
from keras.layers import BatchNormalization, Dropout, GlobalAveragePooling2D
from keras.layers import Lambda, Concatenate, add

from keras import backend as K
from keras.saving import register_keras_serializable

# %%
@register_keras_serializable()
def scaling(x, scale):
    return x * scale

@register_keras_serializable()
def conv2d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              use_bias=False,
              name=None):
    x = Conv2D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               use_bias=use_bias,
               name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, momentum=0.995, epsilon=0.001,
                               scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = _generate_layer_name('Activation', prefix=name)
        x = Activation(activation, name=ac_name)(x)
    return x

@register_keras_serializable()
def _generate_layer_name(name, branch_idx=None, prefix=None):
    if prefix is None:
        return None
    if branch_idx is None:
        return '_'.join((prefix, name))
    return '_'.join((prefix, 'Branch', str(branch_idx), name))

@register_keras_serializable()
def _inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    if block_idx is None:
        prefix = None
    else:
        prefix = '_'.join((block_type, str(block_idx)))
    name_fmt = partial(_generate_layer_name, prefix=prefix)

    if block_type == 'Block35':
        branch_0 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 32, 3, name=name_fmt('Conv2d_0b_3x3', 1))
        branch_2 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0b_3x3', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0c_3x3', 2))
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Block17':
        branch_0 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 128, [1, 7], name=name_fmt('Conv2d_0b_1x7', 1))
        branch_1 = conv2d_bn(branch_1, 128, [7, 1], name=name_fmt('Conv2d_0c_7x1', 1))
        branches = [branch_0, branch_1]
    elif block_type == 'Block8':
        branch_0 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 192, [1, 3], name=name_fmt('Conv2d_0b_1x3', 1))
        branch_1 = conv2d_bn(branch_1, 192, [3, 1], name=name_fmt('Conv2d_0c_3x1', 1))
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "Block35", "Block17" or "Block8", '
                         'but got: ' + str(block_type))

    mixed = Concatenate(axis=channel_axis, name=name_fmt('Concatenate'))(branches)
    up = conv2d_bn(mixed,
                #    K.int_shape(x)[channel_axis],
                   x.shape[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name=name_fmt('Conv2d_1x1'))
    up = Lambda(scaling,
                # output_shape=K.int_shape(up)[1:],
                output_shape=up.shape[1:],
                arguments={'scale': scale})(up)
    x = add([x, up])
    if activation is not None:
        x = Activation(activation, name=name_fmt('Activation'))(x)
    return x

# %%
@register_keras_serializable()
def InceptionResNetV1(input_shape=(160, 160, 3),
                      classes=128,
                      dropout_keep_prob=0.8,
                      weights_path=None):
    inputs = Input(shape=input_shape)
    x = conv2d_bn(inputs, 32, 3, strides=2, padding='valid', name='Conv2d_1a_3x3')
    x = conv2d_bn(x, 32, 3, padding='valid', name='Conv2d_2a_3x3')
    x = conv2d_bn(x, 64, 3, name='Conv2d_2b_3x3')
    x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
    x = conv2d_bn(x, 80, 1, padding='valid', name='Conv2d_3b_1x1')
    x = conv2d_bn(x, 192, 3, padding='valid', name='Conv2d_4a_3x3')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid', name='Conv2d_4b_3x3')

    # 5x Block35 (Inception-ResNet-A block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.17,
                                    block_type='Block35',
                                    block_idx=block_idx)

    # Mixed 6a (Reduction-A block):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    name_fmt = partial(_generate_layer_name, prefix='Mixed_6a')
    branch_0 = conv2d_bn(x,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1, 192, 3, name=name_fmt('Conv2d_0b_3x3', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 2))(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_6a')(branches)

    # 10x Block17 (Inception-ResNet-B block):
    for block_idx in range(1, 11):
        x = _inception_resnet_block(x,
                                    scale=0.1,
                                    block_type='Block17',
                                    block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    name_fmt = partial(_generate_layer_name, prefix='Mixed_7a')
    branch_0 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 0))
    branch_0 = conv2d_bn(branch_0,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_2 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 2))
    branch_2 = conv2d_bn(branch_2, 256, 3, name=name_fmt('Conv2d_0b_3x3', 2))
    branch_2 = conv2d_bn(branch_2,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 2))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 3))(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_7a')(branches)

    # 5x Block8 (Inception-ResNet-C block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.2,
                                    block_type='Block8',
                                    block_idx=block_idx)
    x = _inception_resnet_block(x,
                                scale=1.,
                                activation=None,
                                block_type='Block8',
                                block_idx=6)

    # Classification block
    x = GlobalAveragePooling2D(name='AvgPool')(x)
    x = Dropout(1.0 - dropout_keep_prob, name='Dropout')(x)
    # Bottleneck
    x = Dense(classes, use_bias=False, name='Bottleneck')(x)
    bn_name = _generate_layer_name('BatchNorm', prefix='Bottleneck')
    x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False,
                           name=bn_name)(x)

    # Create model
    model = Model(inputs, x, name='inception_resnet_v1')
    if weights_path is not None:
        model.load_weights(weights_path)

    return model

# %%
model= InceptionResNetV1()

# %% [markdown]
# #### 2) 모델에 가중치 적용

# %%
model= InceptionResNetV1()
# 모델 구조 정의 부분 (InceptionResNetV1 함수 정의가 필요)
facenet_model = InceptionResNetV1()  # 기본 구조 정의

# 가중치 불러오기
weights_path = 'C:/Users/MinKyu/Desktop/project4/weights/facenet_keras_weights.h5'  # 경로 변경 필요
facenet_model.load_weights(weights_path)

print("FaceNet 모델의 가중치가 성공적으로 로드되었습니다.")
# Out:
# FaceNet 모델의 가중치가 성공적으로 로드되었습니다.

# %% [markdown]
# #### 3) 모델의 가중치 업데이트 방지 (선택사항)

# %%
facenet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 구조 출력
facenet_model.summary()
# Out:
# Model: "inception_resnet_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 160, 160, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)        │ (None, 79, 79, 32)        │             864 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm       │ (None, 79, 79, 32)        │              96 │ Conv2d_1a_3x3[0][0]        │
# ...

# %%
## FaceNet 전체 레이어 확인
facenet_model.layers
# Out:
# [<InputLayer name=input_layer_1, built=True>,
#  <Conv2D name=Conv2d_1a_3x3, built=True>,
#  <BatchNormalization name=Conv2d_1a_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_1a_3x3_Activation, built=True>,
#  <Conv2D name=Conv2d_2a_3x3, built=True>,
#  <BatchNormalization name=Conv2d_2a_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_2a_3x3_Activation, built=True>,
#  <Conv2D name=Conv2d_2b_3x3, built=True>,
#  <BatchNormalization name=Conv2d_2b_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_2b_3x3_Activation, built=True>,
#  <MaxPooling2D name=MaxPool_3a_3x3, built=True>,
#  <Conv2D name=Conv2d_3b_1x1, built=True>,
#  <BatchNormalization name=Conv2d_3b_1x1_BatchNorm, built=True>,
#  <Activation name=Conv2d_3b_1x1_Activation, built=True>,
#  <Conv2D name=Conv2d_4a_3x3, built=True>,
#  <BatchNormalization name=Conv2d_4a_3x3_BatchNorm, built=True>,
#  <Activation name=Conv2d_4a_3x3_Activation, built=True>,
#  <Conv2D name=Conv2d_4b_3x3, built=True>,
# ...

# %%
## FaceNet 전체 레이어 가중치 업데이트 방지
for l in facenet_model.layers :
    l.trainable = False

# %% [markdown]
# ### (2) 모델 구조 변형

# %% [markdown]
# * **세부 요구사항**
#     - 우리의 문제에 맞게 모델을 변형해야 합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# FaceNet 모델 구조를 생성합니다.- FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
#  FaceNet 모델 구조 + 구조 추가- FaceNet의 Output은 128차원의 벡터입니다

# %% [markdown]
# 얼굴 임베딩은 얼굴에서 추출된 특성을 표현하는 벡터입니다. 이는 다른 얼굴에서 생성된 벡터와 비교될 수 있습니다. 예를 들어, (일부 측정에 의해) 가까운 다른 벡터는 동일한 사람일 수 있는 반면, (일부 측정에 의해) 다른 벡터는 다른 사람"일 수 있습니다.
#
# 우리가 개발하려는 분류기 모델은 얼굴 임베딩을 입력으로 받아 얼굴의 정체성을 예측합니다. FaceNet 모델은 제공된 얼굴 이미지에서 임베딩을 생성할 것입니다.
#
# FaceNet 모델은 분류기 자체의 일부로 사용되거나 얼굴을 전처리하기 위한 FaceNet 모델을 사용하여 분류기 모델의 입력으로 저장 및 사용 가능한 얼굴 임베딩을 생성할 수 있습니다. 얼굴 임베딩을 생성하기 위한 FaceNet 모델은 크고 느리기 때문에 후자의 접근 방식이 선호됩니다

# %% [markdown]
# ### FaceNet은 전처리, 얼굴에서 특성 추출 후 벡터로 바꿔주는 정도 => 128 output으로 나옴
# ### 이걸 다시 머신러닝이나 딥러닝을 활용해서 분류모델을 만들어서 최종 모델 생성
# #### FaceNet + deeplearning(clasffication) = 최종모델
# #### FaceNet + machine learning(xgb,randomforest,svm,knn,등등)

# %% [markdown]
# #### 1) 추가 모델링

# %%
feature_extractor = Model(inputs=facenet_model.input, outputs=facenet_model.layers[-2].output)  # 마지막 레이어 제외
train_features = feature_extractor.predict(x_train)
test_features = feature_extractor.predict(x_test)
# Out:
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 98s 233ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 23s 224ms/step

# %%
import keras.backend as k

# %%
from keras.models import Sequential
from keras.layers import Dense
k.clear_session()
binary_model = Sequential()

binary_model.add(Dense(1024, activation='relu', input_shape=(train_features.shape[1],)))
binary_model.add(Dropout(0.5))
binary_model.add(Dense(512, activation='relu', input_shape=(train_features.shape[1],)))
binary_model.add(Dropout(0.5))
binary_model.add(Dense(256, activation='relu', input_shape=(train_features.shape[1],)))
binary_model.add(Dropout(0.5))
binary_model.add(Dense(128, activation='relu', input_shape=(train_features.shape[1],)))
binary_model.add(Dropout(0.5))
binary_model.add(Dense(64, activation='relu', input_shape=(train_features.shape[1],)))
binary_model.add(Dropout(0.5))
binary_model.add(Dense(1, activation='sigmoid')) # 이진분류 니까 sigmoid

binary_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\MinKyu\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# C:\Users\MinKyu\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras.callbacks import EarlyStopping

# %%
es = EarlyStopping(
    monitor='val_loss',  # 모니터할 값: 검증 손실
    patience=10,          # 개선이 없을 때 몇 에폭 후에 종료할지 설정
    restore_best_weights=True  # 가장 좋은 모델 가중치 복원
)

# %%
binary_model.fit(train_features, y_train, validation_split = 0.2, epochs=100,callbacks=[es], batch_size=32)
# Out:
# Epoch 1/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 1.1581e-06
# Epoch 2/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 5.0898e-11
# Epoch 3/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9994 - loss: 5.0070e-04 - val_accuracy: 1.0000 - val_loss: 4.1976e-12
# Epoch 4/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 2.5240e-09
# Epoch 5/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 2.3044e-06
# Epoch 6/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9994 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 1.5256e-08
# Epoch 7/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 1.3050e-04
# Epoch 8/100
# ...

# %%
#
loss, accuracy = binary_model.evaluate(test_features, y_test)
print(f'test accuracy: {accuracy * 100:.2f}%')

predictions = binary_model.predict(test_features)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9997 - loss: 2.5176e-04
# test accuracy: 99.97%
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
from keras.models import Model
from keras.layers import Input, Dense, Dropout

input_shape = facenet_model.input_shape[1:]  # (160, 160, 3)

inputs = Input(shape=input_shape)

# FaceNet 모델에 입력 연결
features = facenet_model(inputs)

# 이진 분류 레이어
x = Dense(1024, activation='relu')(features)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(1, activation='sigmoid')(x)  # 이진 분류

combined_model = Model(inputs, outputs)

combined_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

combined_model.summary()
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 160, 160, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1024)                │         132,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 1024)                │               0 │
# ...

# %%
combined_model.fit(x_train , y_train ,validation_split = 0.2, epochs=100,callbacks=[es], batch_size=32)
# Out:
# Epoch 1/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 106s 295ms/step - accuracy: 0.9413 - loss: 0.1329 - val_accuracy: 0.9973 - val_loss: 0.0121
# Epoch 2/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 95s 293ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 0.9985 - val_loss: 0.0099
# Epoch 3/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 98s 301ms/step - accuracy: 0.9975 - loss: 0.0078 - val_accuracy: 0.9988 - val_loss: 0.0110
# Epoch 4/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 100s 309ms/step - accuracy: 0.9975 - loss: 0.0073 - val_accuracy: 0.9992 - val_loss: 0.0064
# Epoch 5/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 98s 302ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.9988 - val_loss: 0.0098
# Epoch 6/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 97s 299ms/step - accuracy: 0.9974 - loss: 0.0100 - val_accuracy: 0.9988 - val_loss: 0.0074
# Epoch 7/100
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 95s 293ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9946 - val_loss: 0.0209
# Epoch 8/100
# ...

# %%
import random
import matplotlib.pyplot as plt

# %%
# 랜덤으로 하나의 인덱스 선택
random_index = random.randint(0, len(x_test) - 1)

# 랜덤 선택한 이미지와 해당 레이블 가져오기
selected_image = x_test[random_index]
true_label = y_test[random_index]

# 예측 수행
predicted_label = binary_model.predict(np.expand_dims(test_features[random_index], axis=0))
predicted_label = (predicted_label > 0.5).astype(int)  # 0.5 기준으로 이진화

# 이미지 출력

plt.imshow(selected_image)
plt.axis('off')  # 축 숨기기
plt.title(f'True Label: {true_label}, Predicted Label: {predicted_label[0][0]}')
plt.show()

# %% [markdown]
# ## 5.미션3

# %% [markdown]
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ### (1) 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 모델 구조를 잘 변형하였다면, 학습도 진행해야 합니다.
#         - Keras에서 지원하는 다양한 함수를 사용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 학습에 유용한 함수 불러오기

# %% [markdown]
# #### 2) 모델 학습

# %% [markdown]
# ### (2) 모델 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습된 모델의 성능을 확인해보세요.
#         - 임계값 조절, 클래스 가중치 부여 등으로 모델의 성능을 높여보세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras, sklearn

# %% [markdown]
# #### 1) 모델 추론

# %% [markdown]
# #### 2) 성능 확인

# %% [markdown]
# ### (3) 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - **반드시 반드시 모델을 저장하고 로컬에 다운로드하세요.**
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 모델 저장

# %%
path
# Out:
# 'C:/Users/MinKyu/Desktop/project4'

# %%
model_save_path = path + '/facenet_model.keras'
combined_model.save(model_save_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[235], line 2
#       1 model_save_path = path + '/facenet_model.keras'
# ----> 2 combined_model.save(model_save_path)
#
# AttributeError: 'str' object has no attribute 'save'

# %%
model_save_path = path + '/facenet_model.keras'
facenet_model.save(model_save_path)

# %%
# 가중치 저장
model_save_path = path +'/binary_model.keras'
binary_model.save(model_save_path)

# %%
## .keras로 저장해야 안전
.save('')

# %% [markdown]
# #### 2) 저장된 모델 체크

# %%
## Colab에 저장된 모델을 불러와 확인
temp_model = keras.saving.load_model('')
temp_model.summary()
